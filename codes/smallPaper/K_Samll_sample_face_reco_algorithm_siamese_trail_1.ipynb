# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Import all the necessary Library 
import torchvision
import torch.utils.data as utils
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset, random_split
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import time
import copy
from torch.optim import lr_scheduler
import os
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
path_lfw_folder='./gdrive/MyDrive/Datasets'

# %%
def count_parameters(model):
    temp = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f'The model architecture:\n\n', model)
    print(f'\nThe model has {temp:,} trainable parameters')

def save_checkpoint(save_path, model, optimizer, val_acc):
    if save_path==None:      
        return
    save_path = save_path 
    state_dict = {'model_state_dict': model.state_dict(),                    
                  'optimizer_state_dict': optimizer.state_dict(),
                  'val_accuracy': val_acc}

    torch.save(state_dict, save_path)

    print(f'Model saved to ==> {save_path}')

def load_checkpoint(model, optimizer,save_path):
    state_dict = torch.load(save_path)
    model.load_state_dict(state_dict['model_state_dict'])
    optimizer.load_state_dict(state_dict['optimizer_state_dict'])
    val_acc = state_dict['val_accuracy']
    print(f'Model loaded from <== {save_path}')
    
    return val_acc

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
class Config():
    training_dir = "./gdrive/MyDrive/Datasets/Cropped_lfw_correct"                                                          
    testing_dir = "./gdrive/MyDrive/Datasets/Cropped_lfw_correct"
    validation_dir="./gdrive/MyDrive/Datasets/Cropped_lfw_correct"
    train_batch_size = 32
    train_number_epochs = 200
    training_txt="./gdrive/MyDrive/Datasets/LWF_DATASET/pairsDevTrainMod.txt"
    testing_txt="./gdrive/MyDrive/Datasets/LWF_DATASET/pairsDevValidMod.txt"

# %%
class SiameseNetworkDataset():
    
    def __init__(self,training_txt=None,training_dir=None,transform=None):
        self.training_dir = training_dir    
        self.transform = transform
        
        with open(training_txt) as f:
          lines=f.readlines()
          self.training_pairs=[  line.split()       for line in lines  ] 
          for i in range(len(self.training_pairs)):
            self.training_pairs[i][2]=int(self.training_pairs[i][2])
            if self.training_pairs[i][2]==1:                                     # 0 for similar pairs and 1 for dissimilar pairs
              self.training_pairs[i][2]=0
            else:
              self.training_pairs[i][2]=1   

    def __getitem__(self,index):
        
        # getting the image path
        image_pair= self.training_pairs[index]
        image1_path=os.path.join(self.training_dir,image_pair[0])
        image2_path=os.path.join(self.training_dir,image_pair[1])
        
        # Loading the image
        img0 = Image.open(image1_path)
        img1 = Image.open(image2_path)
        
        # Apply image transformations
        if self.transform :
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int( image_pair[2] )],dtype=np.float32))
    
    def __len__(self):
        return len(self.training_pairs)

# %%
class SiameseNetwork(nn.Module):  
                                                                                                  #ip size: 120 X 120 X 3
  def __init__(self):

    super(SiameseNetwork, self).__init__()

    self.Conv1_1=  nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True)
    )
    self.Conv1_2=  nn.Sequential(
        nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True)
    )
    self.Pooling1_1= nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

    self.Conv2_1=  nn.Sequential(
        nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True)
    )
    self.Conv2_2=  nn.Sequential(
        nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True)
    )
    self.Pooling2_1= nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

    self.Conv3_1=  nn.Sequential(
        nn.Conv2d(in_channels=128, out_channels=512, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True)
    )
    self.Conv3_2=  nn.Sequential(
        nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True)
    )
    self.Pooling3_1= nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

    self.Conv4=  nn.Sequential(
        nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True)
    )

    self.FC = nn.Sequential(
        nn.Linear(15*15*1024, 400),
        nn.Linear(400, 400),
        nn.Linear(400, 400)
    )
  def forward_simplifier(self,x):
    x= self.Conv1_1(x)
    x= self.Conv1_2(x)
    x= self.Pooling1_1(x)

    x= self.Conv2_1(x)
    x= self.Conv2_2(x)
    x= self.Pooling2_1(x)

    x= self.Conv3_1(x)
    x= self.Conv3_2(x)
    x= self.Pooling3_1(x)

    x= self.Conv4(x)

    x= x.view(-1,15*15*1024)

    x= self.FC(x)

    return x

  def forward(self, input1, input2):                                                  # op dim= 400
    output1= self.forward_simplifier(input1)
    output2= self.forward_simplifier(input2)
    
    return output1, output2

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
      super(ContrastiveLoss, self).__init__()
      self.margin = margin

    def forward(self, output1,output2, label):                                                
      dist = F.pairwise_distance(output1, output2)
      # loss= torch.mean(  (1- label) * (dist) + (label) * ( torch.clamp(   self.margin - dist ,  min=0.0  )   ) )
      # Max  train  acc:  0.5170454545454546            Threshold:  0.01
      # Max  test  acc:  0.503            Threshold:  0.01

      loss= torch.mean(  (1- label) * torch.pow(dist, 2) + (label) * torch.pow( torch.clamp(   self.margin - dist ,  min=0.0  ) , 2)   )
      # Max  train  acc:  0.5852272727272727            Threshold:  0.66
      # Max  test  acc:  0.6            Threshold:  0.62

      return loss

# %%
if torch.cuda.is_available():
  device='cuda:0'
  print('Running on gpu')
else:
  device='cpu'
  print('Running on cpu')
# Out:
# Running on gpu

# %%
def calculate_accuracy(labels,preds,threshold=0.5):
  # preds is a 1 d tensor
  # labels is a (n,1) 2d array

  correct, total=0,0

  for i in range(len(labels)):
    total+=1
    if preds[i]<threshold:  
      # similar predicted
      if labels[i][0]==0.0:
        correct+=1
    else:
      # different predicted
      if labels[i][0]==1.0:
        correct+=1
  return total,correct

# %%
def train(model,train_loader,val_loader,num_epochs,criterion,save_name,optimizer):
  train_losses=[]
  val_losses=[]
  valid_accuracy=[]
  mx_val_accuracy=-1
  counting_batches=0

  for epoch in range(num_epochs):

    running_loss, total_no_imgs = 0.0 , 0
    print("Starting epoch " + str(epoch+1))
    model.train()

    counting_batches=0
    print("Starting training... ")
    for imgs1,imgs2,labels in train_loader:
      counting_batches+=1

      # print("Processing train batch no :",counting_batches)

      imgs1=imgs1.to(device=device, dtype=torch.float)
      imgs2=imgs2.to(device=device, dtype=torch.float)
      labels=labels.to(device=device, dtype=torch.float)

      optimizer.zero_grad()
      
      output1,output2=model(imgs1,imgs2)
      
      # print(output1.size())
      # print(output2.size())

      loss=criterion(output1,output2,labels)                                 
      
      # print(loss)
      # print(loss.item())
      
      loss.backward()
      optimizer.step()

      total_no_imgs+= imgs1.size(0)
      running_loss+=loss.item()* imgs1.size(0)

    avg_train_loss = float(running_loss) /total_no_imgs  
    train_losses.append(avg_train_loss)               

    val_running_loss, correct, total_no_imgs=0.0, 0, 0                                                            
    print("Starting validation... ")
    counting_batches=0
    with torch.no_grad():
      model.eval()
      for i,data in enumerate(val_loader,0):
        counting_batches+=1
        # print("Processing val batch no :",counting_batches)

        imgsV1,imgsV2,labelsV= data
        
        imgsV1=imgsV1.to(device=device, dtype=torch.float)
        imgsV2=imgsV2.to(device=device, dtype=torch.float)
        labelsV=labelsV.to(device=device, dtype=torch.float)

        outputV1, outputV2 = model(imgsV1,imgsV2)
        
        lossV= criterion(outputV1, outputV2,labelsV)
        
        val_running_loss+=lossV.item()*imgsV1.size(0)

        # val accuracy calc 
        outputV1=outputV1.to(device=device, dtype=torch.float)
        outputV2=outputV2.to(device=device, dtype=torch.float)

        dist = F.pairwise_distance(outputV1, outputV2)     # dist will be a 1d array with each element representing dist for each pair  

        noImg,noCrt= calculate_accuracy(labelsV,dist)
        total_no_imgs+=noImg
        correct+=noCrt
        
    val_accuracy= float(correct)/total_no_imgs
    valid_accuracy.append(val_accuracy)
    
    avg_val_loss= float(val_running_loss)/total_no_imgs
    val_losses.append(avg_val_loss)
    
    ## val acc
    if mx_val_accuracy<val_accuracy:
      mx_val_accuracy=val_accuracy
      save_checkpoint(save_name, model, optimizer, mx_val_accuracy)

    print('Epoch [{}/{}],Train Loss: {:.4f}, Valid Loss: {:.8f}'.format(epoch+1, num_epochs, avg_train_loss, avg_val_loss))
  
  print("Training completed.")
  
  fig = plt.figure()
  ax = plt.subplot(111)
  ax.plot(train_losses)
  ax.plot(val_losses)    
  plt.xlabel('Steps')  
  plt.ylabel('Loss')  
  fig.savefig(os.path.join(path_lfw_folder,'Loss_Steps.png')) 

  return model,train_losses,val_losses,mx_val_accuracy,valid_accuracy

# %%
train_dataSize = 2200                                                               
TRAIN_PCT = 0.8 
train_size = int(train_dataSize * TRAIN_PCT)
val_size = train_dataSize - train_size   

siamese_dataset = SiameseNetworkDataset(Config().training_txt,Config().training_dir,
                                        transform=transforms.Compose([transforms.Resize(( 120,120 )),
                                                                      transforms.ToTensor()
                                                                      ])
                                      )

train_set, val_set = random_split(siamese_dataset, [train_size, val_size])


train_loader = DataLoader(train_set, shuffle=True,batch_size=Config().train_batch_size , num_workers=2)    
val_loader   = DataLoader(val_set, shuffle=True, batch_size=1,  num_workers=2)

# %%
# Viewing the sample of images and to check whether its loading properly
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
print(example_batch[2])
# Out:
# [[0.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]
#  [1.]
#  [0.]
#  [0.]]
# tensor([[0.],
#         [1.],
#         [1.],
#         [0.],
#         [0.],
#         [1.],
#         [0.],
#         [0.]])

# %%
net = SiameseNetwork().cuda()

criterion = ContrastiveLoss()

optimizer = optim.Adam(net.parameters(), lr=0.00005)

count_parameters(net)
# Out:
# The model architecture:
#
#  SiameseNetwork(
#   (Conv1_1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Conv1_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Pooling1_1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2_1): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Conv2_2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Pooling2_1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv3_1): Sequential(
#     (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Conv3_2): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Pooling3_1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv4): Sequential(
#     (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (FC): Sequential(
#     (0): Linear(in_features=230400, out_features=400, bias=True)
#     (1): Linear(in_features=400, out_features=400, bias=True)
#     (2): Linear(in_features=400, out_features=400, bias=True)
#   )
# )
#
# The model has 100,253,456 trainable parameters

# %%
save_path=os.path.join(path_lfw_folder,'Samll_sample_face_reco_algorithm_siamese_best_val_acc.pt')

# %%
longest_trained_model,train_loss_his,val_loss_his,mx_val_accuracy_train,validation_accu=train(net,train_loader,val_loader,Config().train_number_epochs,criterion,save_path,optimizer)
# Out:
# Starting epoch 1
# Starting training...
# Starting validation...
# Model saved to ==> ./gdrive/MyDrive/Datasets/Samll_sample_face_reco_algorithm_siamese_best_val_acc.pt
# Epoch [1/200],Train Loss: 1.3063, Valid Loss: 1.01551994
# Starting epoch 2
# Starting training...
# Starting validation...
# Model saved to ==> ./gdrive/MyDrive/Datasets/Samll_sample_face_reco_algorithm_siamese_best_val_acc.pt
# Epoch [2/200],Train Loss: 1.1480, Valid Loss: 0.96671910
# Starting epoch 3
# Starting training...
# Starting validation...
# Epoch [3/200],Train Loss: 1.1136, Valid Loss: 1.00548096
# Starting epoch 4
# Starting training...
# Starting validation...
# Epoch [4/200],Train Loss: 1.1186, Valid Loss: 0.96100332
# Starting epoch 5
# Starting training...
# Starting validation...
# Epoch [5/200],Train Loss: 1.0844, Valid Loss: 0.97450683
# Starting epoch 6
# Starting training...
# Starting validation...
# Epoch [6/200],Train Loss: 1.0717, Valid Loss: 0.95640439
# Starting epoch 7
# Starting training...
# Starting validation...
# Epoch [7/200],Train Loss: 1.0706, Valid Loss: 0.97292432
# Starting epoch 8
# Starting training...
# Starting validation...
# Model saved to ==> ./gdrive/MyDrive/Datasets/Samll_sample_face_reco_algorithm_siamese_best_val_acc.pt
# Epoch [8/200],Train Loss: 1.0601, Valid Loss: 1.13485404
# Starting epoch 9
# Starting training...
# Starting validation...
# Epoch [9/200],Train Loss: 1.0875, Valid Loss: 0.98398293
# Starting epoch 10
# Starting training...
# Starting validation...
# Epoch [10/200],Train Loss: 1.0740, Valid Loss: 0.96502542
# Starting epoch 11
# Starting training...
# Starting validation...
# Epoch [11/200],Train Loss: 1.0517, Valid Loss: 0.96214929
# Starting epoch 12
# Starting training...
# Starting validation...
# Epoch [12/200],Train Loss: 1.0675, Valid Loss: 0.97107378
# Starting epoch 13
# Starting training...
# Starting validation...
# Epoch [13/200],Train Loss: 1.0533, Valid Loss: 0.98254467
# Starting epoch 14
# Starting training...
# Starting validation...
# Epoch [14/200],Train Loss: 1.0369, Valid Loss: 0.98238513
# Starting epoch 15
# Starting training...
# Starting validation...
# Epoch [15/200],Train Loss: 1.0593, Valid Loss: 0.96010729
# Starting epoch 16
# Starting training...
# Starting validation...
# Epoch [16/200],Train Loss: 1.0342, Valid Loss: 0.97488911
# Starting epoch 17
# Starting training...
# Starting validation...
# Epoch [17/200],Train Loss: 1.0301, Valid Loss: 0.96651506
# Starting epoch 18
# Starting training...
# Starting validation...
# Epoch [18/200],Train Loss: 1.0249, Valid Loss: 0.96597644
# Starting epoch 19
# Starting training...
# Starting validation...
# Epoch [19/200],Train Loss: 1.0196, Valid Loss: 0.96757057
# Starting epoch 20
# Starting training...
# Starting validation...
# Epoch [20/200],Train Loss: 1.0192, Valid Loss: 0.97660913
# Starting epoch 21
# Starting training...
# Starting validation...
# Epoch [21/200],Train Loss: 1.0513, Valid Loss: 0.98644472
# Starting epoch 22
# Starting training...
# Starting validation...
# Epoch [22/200],Train Loss: 1.0242, Valid Loss: 0.97098237
# Starting epoch 23
# Starting training...
# Starting validation...
# Epoch [23/200],Train Loss: 1.0220, Valid Loss: 0.97122156
# Starting epoch 24
# Starting training...
# Starting validation...
# Epoch [24/200],Train Loss: 1.0282, Valid Loss: 0.99519433
# Starting epoch 25
# Starting training...
# Starting validation...
# Epoch [25/200],Train Loss: 1.0208, Valid Loss: 0.98251157
# Starting epoch 26
# Starting training...
# Starting validation...
# Epoch [26/200],Train Loss: 1.0177, Valid Loss: 0.97365331
# Starting epoch 27
# Starting training...
# Starting validation...
# Epoch [27/200],Train Loss: 1.0136, Valid Loss: 0.98109731
# Starting epoch 28
# Starting training...
# Starting validation...
# Epoch [28/200],Train Loss: 1.0214, Valid Loss: 0.97375566
# Starting epoch 29
# Starting training...
# Starting validation...
# Epoch [29/200],Train Loss: 1.0186, Valid Loss: 1.00690804
# Starting epoch 30
# Starting training...
# Starting validation...
# Epoch [30/200],Train Loss: 1.0215, Valid Loss: 0.98573946
# Starting epoch 31
# Starting training...
# Starting validation...
# Epoch [31/200],Train Loss: 1.0148, Valid Loss: 0.98053693
# Starting epoch 32
# Starting training...
# Starting validation...
# Epoch [32/200],Train Loss: 1.0140, Valid Loss: 1.00362258
# Starting epoch 33
# Starting training...
# Starting validation...
# Epoch [33/200],Train Loss: 1.0193, Valid Loss: 0.98780461
# Starting epoch 34
# Starting training...
# Starting validation...
# Epoch [34/200],Train Loss: 1.0102, Valid Loss: 0.99073825
# Starting epoch 35
# Starting training...
# Starting validation...
# Epoch [35/200],Train Loss: 1.0205, Valid Loss: 0.98869197
# Starting epoch 36
# Starting training...
# Starting validation...
# Epoch [36/200],Train Loss: 1.0181, Valid Loss: 0.96743196
# Starting epoch 37
# Starting training...
# Starting validation...
# Epoch [37/200],Train Loss: 1.0129, Valid Loss: 1.02931365
# Starting epoch 38
# Starting training...
# Starting validation...
# Epoch [38/200],Train Loss: 1.0178, Valid Loss: 0.98372736
# Starting epoch 39
# Starting training...
# Starting validation...
# Epoch [39/200],Train Loss: 1.0354, Valid Loss: 0.98088652
# Starting epoch 40
# Starting training...
# Starting validation...
# Epoch [40/200],Train Loss: 1.0141, Valid Loss: 0.97363805
# Starting epoch 41
# Starting training...
# Starting validation...
# Epoch [41/200],Train Loss: 1.0156, Valid Loss: 0.97837156
# Starting epoch 42
# Starting training...
# Starting validation...
# Epoch [42/200],Train Loss: 1.0155, Valid Loss: 0.97720589
# Starting epoch 43
# Starting training...
# Starting validation...
# Epoch [43/200],Train Loss: 1.0189, Valid Loss: 0.98326448
# Starting epoch 44
# Starting training...
# Starting validation...
# Epoch [44/200],Train Loss: 1.0120, Valid Loss: 0.97807894
# Starting epoch 45
# Starting training...
# Starting validation...
# Epoch [45/200],Train Loss: 1.0149, Valid Loss: 1.01830386
# Starting epoch 46
# Starting training...
# Starting validation...
# Epoch [46/200],Train Loss: 1.0214, Valid Loss: 0.98147098
# Starting epoch 47
# Starting training...
# Starting validation...
# Epoch [47/200],Train Loss: 1.0164, Valid Loss: 0.97657696
# Starting epoch 48
# Starting training...
# Starting validation...
# Epoch [48/200],Train Loss: 1.0119, Valid Loss: 0.97597591
# Starting epoch 49
# Starting training...
# Starting validation...
# Epoch [49/200],Train Loss: 1.0081, Valid Loss: 0.97647100
# Starting epoch 50
# Starting training...
# Starting validation...
# Epoch [50/200],Train Loss: 1.0087, Valid Loss: 0.97580944
# Starting epoch 51
# Starting training...
# Starting validation...
# Epoch [51/200],Train Loss: 1.0081, Valid Loss: 0.96671505
# Starting epoch 52
# Starting training...
# Starting validation...
# Epoch [52/200],Train Loss: 1.0097, Valid Loss: 1.02106784
# Starting epoch 53
# Starting training...
# Starting validation...
# Epoch [53/200],Train Loss: 1.0163, Valid Loss: 0.97388859
# Starting epoch 54
# Starting training...
# Starting validation...
# Epoch [54/200],Train Loss: 1.0164, Valid Loss: 0.97740525
# Starting epoch 55
# Starting training...
# Starting validation...
# Epoch [55/200],Train Loss: 1.0122, Valid Loss: 0.97370995
# Starting epoch 56
# Starting training...
# Starting validation...
# Epoch [56/200],Train Loss: 1.0141, Valid Loss: 0.96145554
# Starting epoch 57
# Starting training...
# Starting validation...
# Epoch [57/200],Train Loss: 1.0101, Valid Loss: 0.97418610
# Starting epoch 58
# Starting training...
# Starting validation...
# Epoch [58/200],Train Loss: 1.0212, Valid Loss: 0.96687764
# Starting epoch 59
# Starting training...
# Starting validation...
# Epoch [59/200],Train Loss: 1.0259, Valid Loss: 0.98997363
# Starting epoch 60
# Starting training...
# Starting validation...
# Epoch [60/200],Train Loss: 1.0172, Valid Loss: 0.97055577
# Starting epoch 61
# Starting training...
# Starting validation...
# Epoch [61/200],Train Loss: 1.0153, Valid Loss: 0.97298800
# Starting epoch 62
# Starting training...
# Starting validation...
# Epoch [62/200],Train Loss: 1.0077, Valid Loss: 0.97069443
# Starting epoch 63
# Starting training...
# Starting validation...
# Epoch [63/200],Train Loss: 1.0097, Valid Loss: 0.99827107
# Starting epoch 64
# Starting training...
# Starting validation...
# Epoch [64/200],Train Loss: 1.0080, Valid Loss: 0.97269440
# Starting epoch 65
# Starting training...
# Starting validation...
# Epoch [65/200],Train Loss: 1.0071, Valid Loss: 0.97835938
# Starting epoch 66
# Starting training...
# Starting validation...
# Epoch [66/200],Train Loss: 1.0079, Valid Loss: 0.97033536
# Starting epoch 67
# Starting training...
# Starting validation...
# Epoch [67/200],Train Loss: 1.0077, Valid Loss: 0.99309788
# Starting epoch 68
# Starting training...
# Starting validation...
# Epoch [68/200],Train Loss: 1.0112, Valid Loss: 1.01662287
# Starting epoch 69
# Starting training...
# Starting validation...
# Epoch [69/200],Train Loss: 1.0163, Valid Loss: 0.96843678
# Starting epoch 70
# Starting training...
# Starting validation...
# Epoch [70/200],Train Loss: 1.0155, Valid Loss: 0.98034148
# Starting epoch 71
# Starting training...
# Starting validation...
# Epoch [71/200],Train Loss: 1.0098, Valid Loss: 0.99507626
# Starting epoch 72
# Starting training...
# Starting validation...
# Epoch [72/200],Train Loss: 1.0099, Valid Loss: 0.98029277
# Starting epoch 73
# Starting training...
# Starting validation...
# Epoch [73/200],Train Loss: 1.0265, Valid Loss: 0.98260626
# Starting epoch 74
# Starting training...
# Starting validation...
# Epoch [74/200],Train Loss: 1.0082, Valid Loss: 0.98868745
# Starting epoch 75
# Starting training...
# Starting validation...
# Epoch [75/200],Train Loss: 1.0135, Valid Loss: 0.97809663
# Starting epoch 76
# Starting training...
# Starting validation...
# Epoch [76/200],Train Loss: 1.0201, Valid Loss: 0.97625064
# Starting epoch 77
# Starting training...
# Starting validation...
# Epoch [77/200],Train Loss: 1.0189, Valid Loss: 0.98633007
# Starting epoch 78
# Starting training...
# Starting validation...
# Epoch [78/200],Train Loss: 1.0129, Valid Loss: 0.99236739
# Starting epoch 79
# Starting training...
# Starting validation...
# Epoch [79/200],Train Loss: 1.0114, Valid Loss: 0.99814186
# Starting epoch 80
# Starting training...
# Starting validation...
# Epoch [80/200],Train Loss: 1.0151, Valid Loss: 0.97283017
# Starting epoch 81
# Starting training...
# Starting validation...
# Epoch [81/200],Train Loss: 1.0083, Valid Loss: 0.96790854
# Starting epoch 82
# Starting training...
# Starting validation...
# Epoch [82/200],Train Loss: 1.0075, Valid Loss: 0.97662413
# Starting epoch 83
# Starting training...
# Starting validation...
# Epoch [83/200],Train Loss: 1.0106, Valid Loss: 0.96804053
# Starting epoch 84
# Starting training...
# Starting validation...
# Epoch [84/200],Train Loss: 1.0105, Valid Loss: 0.97486285
# Starting epoch 85
# Starting training...
# Starting validation...
# Epoch [85/200],Train Loss: 1.0104, Valid Loss: 0.97550240
# Starting epoch 86
# Starting training...
# Starting validation...
# Epoch [86/200],Train Loss: 1.0149, Valid Loss: 0.98431104
# Starting epoch 87
# Starting training...
# Starting validation...
# Epoch [87/200],Train Loss: 1.0092, Valid Loss: 0.96991664
# Starting epoch 88
# Starting training...
# Starting validation...
# Epoch [88/200],Train Loss: 1.0065, Valid Loss: 0.97749287
# Starting epoch 89
# Starting training...
# Starting validation...
# Epoch [89/200],Train Loss: 1.0123, Valid Loss: 0.98676615
# Starting epoch 90
# Starting training...
# Starting validation...
# Epoch [90/200],Train Loss: 1.0163, Valid Loss: 0.97833743
# Starting epoch 91
# Starting training...
# Starting validation...
# Epoch [91/200],Train Loss: 1.0067, Valid Loss: 0.96745362
# Starting epoch 92
# Starting training...
# Starting validation...
# Epoch [92/200],Train Loss: 1.0078, Valid Loss: 0.99422195
# Starting epoch 93
# Starting training...
# Starting validation...
# Epoch [93/200],Train Loss: 1.0188, Valid Loss: 0.98667742
# Starting epoch 94
# Starting training...
# Starting validation...
# Epoch [94/200],Train Loss: 1.0138, Valid Loss: 0.97060015
# Starting epoch 95
# Starting training...
# Starting validation...
# Epoch [95/200],Train Loss: 1.0124, Valid Loss: 0.97056289
# Starting epoch 96
# Starting training...
# Starting validation...
# Epoch [96/200],Train Loss: 1.0067, Valid Loss: 0.98256691
# Starting epoch 97
# Starting training...
# Starting validation...
# Epoch [97/200],Train Loss: 1.0084, Valid Loss: 0.97258458
# Starting epoch 98
# Starting training...
# Starting validation...
# Epoch [98/200],Train Loss: 1.0070, Valid Loss: 0.97183572
# Starting epoch 99
# Starting training...
# Starting validation...
# Epoch [99/200],Train Loss: 1.0223, Valid Loss: 0.98299320
# Starting epoch 100
# Starting training...
# Starting validation...
# Epoch [100/200],Train Loss: 1.0092, Valid Loss: 0.96917404
# Starting epoch 101
# Starting training...
# Starting validation...
# Epoch [101/200],Train Loss: 1.0105, Valid Loss: 0.97146441
# Starting epoch 102
# Starting training...
# Starting validation...
# Epoch [102/200],Train Loss: 1.0089, Valid Loss: 0.97345538
# Starting epoch 103
# Starting training...
# Starting validation...
# Epoch [103/200],Train Loss: 1.0076, Valid Loss: 0.96795561
# Starting epoch 104
# Starting training...
# Starting validation...
# Epoch [104/200],Train Loss: 1.0052, Valid Loss: 0.98068838
# Starting epoch 105
# Starting training...
# Starting validation...
# Epoch [105/200],Train Loss: 1.0089, Valid Loss: 0.97870439
# Starting epoch 106
# Starting training...
# Starting validation...
# Epoch [106/200],Train Loss: 1.0058, Valid Loss: 0.97847057
# Starting epoch 107
# Starting training...
# Starting validation...
# Epoch [107/200],Train Loss: 1.0079, Valid Loss: 0.96942275
# Starting epoch 108
# Starting training...
# Starting validation...
# Epoch [108/200],Train Loss: 1.0059, Valid Loss: 0.97631072
# Starting epoch 109
# Starting training...
# Starting validation...
# Epoch [109/200],Train Loss: 1.0084, Valid Loss: 1.00149734
# Starting epoch 110
# Starting training...
# Starting validation...
# Epoch [110/200],Train Loss: 1.0097, Valid Loss: 1.00532745
# Starting epoch 111
# Starting training...
# Starting validation...
# Epoch [111/200],Train Loss: 1.0102, Valid Loss: 0.97912687
# Starting epoch 112
# Starting training...
# Starting validation...
# Epoch [112/200],Train Loss: 1.0166, Valid Loss: 0.98219640
# Starting epoch 113
# Starting training...
# Starting validation...
# Epoch [113/200],Train Loss: 1.0076, Valid Loss: 0.97680122
# Starting epoch 114
# Starting training...
# Starting validation...
# Epoch [114/200],Train Loss: 1.0067, Valid Loss: 0.96857953
# Starting epoch 115
# Starting training...
# Starting validation...
# Epoch [115/200],Train Loss: 1.0063, Valid Loss: 0.98301245
# Starting epoch 116
# Starting training...
# Starting validation...
# Epoch [116/200],Train Loss: 1.0117, Valid Loss: 0.97821625
# Starting epoch 117
# Starting training...
# Starting validation...
# Epoch [117/200],Train Loss: 1.0053, Valid Loss: 0.98208897
# Starting epoch 118
# Starting training...
# Starting validation...
# Epoch [118/200],Train Loss: 1.0073, Valid Loss: 0.97195149
# Starting epoch 119
# Starting training...
# Starting validation...
# Epoch [119/200],Train Loss: 1.0095, Valid Loss: 0.97239032
# Starting epoch 120
# Starting training...
# Starting validation...
# Epoch [120/200],Train Loss: 1.0117, Valid Loss: 0.97829718
# Starting epoch 121
# Starting training...
# Starting validation...
# Epoch [121/200],Train Loss: 1.0124, Valid Loss: 0.98116444
# Starting epoch 122
# Starting training...
# Starting validation...
# Epoch [122/200],Train Loss: 1.0148, Valid Loss: 1.00789735
# Starting epoch 123
# Starting training...
# Starting validation...
# Epoch [123/200],Train Loss: 1.0110, Valid Loss: 0.97510770
# Starting epoch 124
# Starting training...
# Starting validation...
# Epoch [124/200],Train Loss: 1.0180, Valid Loss: 0.97267716
# Starting epoch 125
# Starting training...
# Starting validation...
# Epoch [125/200],Train Loss: 1.0070, Valid Loss: 0.96822682
# Starting epoch 126
# Starting training...
# Starting validation...
# Epoch [126/200],Train Loss: 1.0095, Valid Loss: 0.97929571
# Starting epoch 127
# Starting training...
# Starting validation...
# Epoch [127/200],Train Loss: 1.0105, Valid Loss: 0.96807704
# Starting epoch 128
# Starting training...
# Starting validation...
# Epoch [128/200],Train Loss: 1.0072, Valid Loss: 0.96808648
# Starting epoch 129
# Starting training...
# Starting validation...
# Epoch [129/200],Train Loss: 1.0058, Valid Loss: 0.97317362
# Starting epoch 130
# Starting training...
# Starting validation...
# Epoch [130/200],Train Loss: 1.0072, Valid Loss: 0.97206369
# Starting epoch 131
# Starting training...
# Starting validation...
# Epoch [131/200],Train Loss: 1.0055, Valid Loss: 0.97705385
# Starting epoch 132
# Starting training...
# Starting validation...
# Epoch [132/200],Train Loss: 1.0117, Valid Loss: 0.97052288
# Starting epoch 133
# Starting training...
# Starting validation...
# Epoch [133/200],Train Loss: 1.0111, Valid Loss: 0.96551250
# Starting epoch 134
# Starting training...
# Starting validation...
# Epoch [134/200],Train Loss: 1.0104, Valid Loss: 0.96840880
# Starting epoch 135
# Starting training...
# Starting validation...
# Epoch [135/200],Train Loss: 1.0094, Valid Loss: 0.98001174
# Starting epoch 136
# Starting training...
# Starting validation...
# Epoch [136/200],Train Loss: 1.0107, Valid Loss: 0.96820945
# Starting epoch 137
# Starting training...
# Starting validation...
# Epoch [137/200],Train Loss: 1.0098, Valid Loss: 0.97227627
# Starting epoch 138
# Starting training...
# Starting validation...
# Epoch [138/200],Train Loss: 1.0154, Valid Loss: 0.97760916
# Starting epoch 139
# Starting training...
# Starting validation...
# Epoch [139/200],Train Loss: 1.0191, Valid Loss: 0.97588105
# Starting epoch 140
# Starting training...
# Starting validation...
# Epoch [140/200],Train Loss: 1.0061, Valid Loss: 0.96827756
# Starting epoch 141
# Starting training...
# Starting validation...
# Epoch [141/200],Train Loss: 1.0082, Valid Loss: 0.97050683
# Starting epoch 142
# Starting training...
# Starting validation...
# Epoch [142/200],Train Loss: 1.0076, Valid Loss: 0.97270861
# Starting epoch 143
# Starting training...
# Starting validation...
# Epoch [143/200],Train Loss: 1.0123, Valid Loss: 1.00394573
# Starting epoch 144
# Starting training...
# Starting validation...
# Epoch [144/200],Train Loss: 1.0059, Valid Loss: 0.97166442
# Starting epoch 145
# Starting training...
# Starting validation...
# Epoch [145/200],Train Loss: 1.0056, Valid Loss: 0.96749272
# Starting epoch 146
# Starting training...
# Starting validation...
# Epoch [146/200],Train Loss: 1.0057, Valid Loss: 0.96396577
# Starting epoch 147
# Starting training...
# Starting validation...
# Epoch [147/200],Train Loss: 1.0051, Valid Loss: 0.96823723
# Starting epoch 148
# Starting training...
# Starting validation...
# Epoch [148/200],Train Loss: 1.0080, Valid Loss: 0.96131428
# Starting epoch 149
# Starting training...
# Starting validation...
# Epoch [149/200],Train Loss: 1.0132, Valid Loss: 0.98646031
# Starting epoch 150
# Starting training...
# Starting validation...
# Epoch [150/200],Train Loss: 1.0049, Valid Loss: 0.97498236
# Starting epoch 151
# Starting training...
# Starting validation...
# Epoch [151/200],Train Loss: 1.0100, Valid Loss: 1.03036511
# Starting epoch 152
# Starting training...
# Starting validation...
# Epoch [152/200],Train Loss: 1.0167, Valid Loss: 0.97024964
# Starting epoch 153
# Starting training...
# Starting validation...
# Epoch [153/200],Train Loss: 1.0071, Valid Loss: 0.98191680
# Starting epoch 154
# Starting training...
# Starting validation...
# Epoch [154/200],Train Loss: 1.0130, Valid Loss: 0.97329957
# Starting epoch 155
# Starting training...
# Starting validation...
# Epoch [155/200],Train Loss: 1.0073, Valid Loss: 0.98061965
# Starting epoch 156
# Starting training...
# Starting validation...
# Epoch [156/200],Train Loss: 1.0093, Valid Loss: 0.97617414
# Starting epoch 157
# Starting training...
# Starting validation...
# Epoch [157/200],Train Loss: 1.0038, Valid Loss: 0.97578928
# Starting epoch 158
# Starting training...
# Starting validation...
# Epoch [158/200],Train Loss: 1.0107, Valid Loss: 0.97267395
# Starting epoch 159
# Starting training...
# Starting validation...
# Epoch [159/200],Train Loss: 1.0059, Valid Loss: 0.97006021
# Starting epoch 160
# Starting training...
# Starting validation...
# Epoch [160/200],Train Loss: 1.0033, Valid Loss: 0.96987022
# Starting epoch 161
# Starting training...
# Starting validation...
# Epoch [161/200],Train Loss: 1.0036, Valid Loss: 1.01605144
# Starting epoch 162
# Starting training...
# Starting validation...
# Epoch [162/200],Train Loss: 1.0154, Valid Loss: 0.97855780
# Starting epoch 163
# Starting training...
# Starting validation...
# Epoch [163/200],Train Loss: 1.0081, Valid Loss: 0.96866630
# Starting epoch 164
# Starting training...
# Starting validation...
# Epoch [164/200],Train Loss: 1.0069, Valid Loss: 0.97168840
# Starting epoch 165
# Starting training...
# Starting validation...
# Epoch [165/200],Train Loss: 1.0243, Valid Loss: 0.98246861
# Starting epoch 166
# Starting training...
# Starting validation...
# Epoch [166/200],Train Loss: 1.0168, Valid Loss: 0.97444070
# Starting epoch 167
# Starting training...
# Starting validation...
# Epoch [167/200],Train Loss: 1.0060, Valid Loss: 0.96922326
# Starting epoch 168
# Starting training...
# Starting validation...
# Epoch [168/200],Train Loss: 1.0071, Valid Loss: 0.99120981
# Starting epoch 169
# Starting training...
# Starting validation...
# Epoch [169/200],Train Loss: 1.0099, Valid Loss: 0.96935891
# Starting epoch 170
# Starting training...
# Starting validation...
# Epoch [170/200],Train Loss: 1.0083, Valid Loss: 0.98025571
# Starting epoch 171
# Starting training...
# Starting validation...
# Epoch [171/200],Train Loss: 1.0075, Valid Loss: 0.97104273
# Starting epoch 172
# Starting training...
# Starting validation...
# Epoch [172/200],Train Loss: 1.0062, Valid Loss: 0.97053263
# Starting epoch 173
# Starting training...
# Starting validation...
# Epoch [173/200],Train Loss: 1.0090, Valid Loss: 0.96472904
# Starting epoch 174
# Starting training...
# Starting validation...
# Epoch [174/200],Train Loss: 1.0099, Valid Loss: 0.96223787
# Starting epoch 175
# Starting training...
# Starting validation...
# Epoch [175/200],Train Loss: 1.0055, Valid Loss: 0.96254942
# Starting epoch 176
# Starting training...
# Starting validation...
# Epoch [176/200],Train Loss: 1.0047, Valid Loss: 0.96925355
# Starting epoch 177
# Starting training...
# Starting validation...
# Epoch [177/200],Train Loss: 1.0108, Valid Loss: 0.97681896
# Starting epoch 178
# Starting training...
# Starting validation...
# Epoch [178/200],Train Loss: 1.0109, Valid Loss: 0.97022973
# Starting epoch 179
# Starting training...
# Starting validation...
# Epoch [179/200],Train Loss: 1.0150, Valid Loss: 0.97377763
# Starting epoch 180
# Starting training...
# Starting validation...
# Epoch [180/200],Train Loss: 1.0058, Valid Loss: 0.98132653
# Starting epoch 181
# Starting training...
# Starting validation...
# Epoch [181/200],Train Loss: 1.0074, Valid Loss: 0.98151244
# Starting epoch 182
# Starting training...
# Starting validation...
# Epoch [182/200],Train Loss: 1.0036, Valid Loss: 0.98654702
# Starting epoch 183
# Starting training...
# Starting validation...
# Epoch [183/200],Train Loss: 1.0101, Valid Loss: 0.97334998
# Starting epoch 184
# Starting training...
# Starting validation...
# Epoch [184/200],Train Loss: 1.0074, Valid Loss: 0.98377313
# Starting epoch 185
# Starting training...
# Starting validation...
# Epoch [185/200],Train Loss: 1.0060, Valid Loss: 0.98653480
# Starting epoch 186
# Starting training...
# Starting validation...
# Epoch [186/200],Train Loss: 1.0063, Valid Loss: 0.99010084
# Starting epoch 187
# Starting training...
# Starting validation...
# Epoch [187/200],Train Loss: 1.0071, Valid Loss: 0.98058506
# Starting epoch 188
# Starting training...
# Starting validation...
# Epoch [188/200],Train Loss: 1.0061, Valid Loss: 0.97879935
# Starting epoch 189
# Starting training...
# Starting validation...
# Epoch [189/200],Train Loss: 1.0064, Valid Loss: 0.97720594
# Starting epoch 190
# Starting training...
# Starting validation...
# Epoch [190/200],Train Loss: 1.0073, Valid Loss: 0.98767560
# Starting epoch 191
# Starting training...
# Starting validation...
# Epoch [191/200],Train Loss: 1.0140, Valid Loss: 0.98646509
# Starting epoch 192
# Starting training...
# Starting validation...
# Epoch [192/200],Train Loss: 1.0079, Valid Loss: 0.97761511
# Starting epoch 193
# Starting training...
# Starting validation...
# Epoch [193/200],Train Loss: 1.0092, Valid Loss: 0.98100512
# Starting epoch 194
# Starting training...
# Starting validation...
# Epoch [194/200],Train Loss: 1.0035, Valid Loss: 0.97779780
# Starting epoch 195
# Starting training...
# Starting validation...
# Epoch [195/200],Train Loss: 1.0087, Valid Loss: 0.98163902
# Starting epoch 196
# Starting training...
# Starting validation...
# Epoch [196/200],Train Loss: 1.0116, Valid Loss: 0.97688225
# Starting epoch 197
# Starting training...
# Starting validation...
# Epoch [197/200],Train Loss: 1.0117, Valid Loss: 0.97232343
# Starting epoch 198
# Starting training...
# Starting validation...
# Epoch [198/200],Train Loss: 1.0069, Valid Loss: 0.97408575
# Starting epoch 199
# Starting training...
# Starting validation...
# Epoch [199/200],Train Loss: 1.0031, Valid Loss: 0.98249410
# Starting epoch 200
# Starting training...
# Starting validation...
# Epoch [200/200],Train Loss: 1.0055, Valid Loss: 0.97638075
# Training completed.

# %%
save_checkpoint(os.path.join(path_lfw_folder,'Samll_sample_face_reco_algorithm_siamese_longest_trained.pt'), longest_trained_model, optimizer, mx_val_accuracy_train)
# Out:
# Model saved to ==> ./gdrive/MyDrive/Datasets/Samll_sample_face_reco_algorithm_siamese_longest_trained.pt

# %%
# lr=    batch=   epoch=
plt.ylabel('loss')
plt.plot(train_loss_his, label='Train Loss')
plt.plot(val_loss_his, label='Validation Loss')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %%
# lr=    batch=   epoch=
plt.ylabel('validation accuracy')
plt.plot(validation_accu, label='Validation accuracy')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %% [markdown]
# Run right from below

# %%
def test(model,test_loader):
    test_distances=[]
    test_labels=[]

    with torch.no_grad():
      model.eval()
      correct=0
      cnt=0
      for i,data in enumerate(test_loader,0):
        
        imgs1,imgs2,labels=data
        
        imgs1=imgs1.to(device=device, dtype=torch.float)
        imgs2=imgs2.to(device=device, dtype=torch.float)
        labels=labels.to(device=device, dtype=torch.float)

        output1,output2=model(imgs1,imgs2)

        dist = F.pairwise_distance(output1, output2)     # dist will be a 1d array with each element representing dist for each pair  

        test_distances.extend(dist)
        test_labels.extend(labels)

    return test_distances, test_labels

# %%
def generate_model_path(model_name):
  
  root_path_to_saved_models=path_lfw_folder
  path_to_model_from_saved_model_dir=model_name
  path_to_chosen_model= os.path.join(root_path_to_saved_models,path_to_model_from_saved_model_dir)  
  
  return path_to_chosen_model

def generate_optm_model():
  load_model= SiameseNetwork().cuda()
  load_optimizer = optim.Adam(load_model.parameters(), lr=0.00005)                                              # set parameters and lr
  return load_model,load_optimizer

def generate_test_loader():
  siamese_dataset_test = SiameseNetworkDataset(Config().testing_txt,Config().testing_dir,
                                          transform=transforms.Compose([transforms.Resize(( 120,120 )),
                                                                        transforms.ToTensor()
                                                    ])
                                          )
  test_loader = DataLoader(siamese_dataset_test , shuffle=True, batch_size=1,  num_workers=2)

  return test_loader

def find_threshold(data_loader, thresholds, load_model):

  accuracies=[]
  print('Loading results...')
  test_distances, test_labels= test(load_model,data_loader)
  print('Finished loading results...')
  for threshold in thresholds:
    print("starting with threshold: ",threshold)
    noImg,noCrt= calculate_accuracy(test_labels,test_distances,threshold)
    accuracy= float(noCrt)/noImg
    accuracies.append(accuracy)
    print("finished with threshold: ",threshold)
  return accuracies

def plot_x_y(label,x,y,graph_label):
  plt.ylabel(label)

  plt.plot(x , y , label=graph_label)

  plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

  plt.show()

def find_max_accuracies(thresholds, accuracies, TYPE):
  mx_ac=-1
  mx_ind=-1

  for i in range(0,len(thresholds)):

    if mx_ac< accuracies[i]:
      mx_ac= accuracies[i]
      mx_ind=i

  print("Max ",TYPE," acc: ",mx_ac,"           Threshold: ",thresholds[mx_ind])

  return mx_ac, thresholds[mx_ind]

def Load_saved_model(model_name):
  
  load_model, load_optimizer= generate_optm_model()

  path_to_chosen_model= generate_model_path(model_name)

  load_checkpoint(load_model,load_optimizer,path_to_chosen_model)

  return load_model, load_optimizer

# %%
thresholds=[i for i in np.arange(0.0,2.0,0.01) ]

# %%
load_model, load_optimizer= Load_saved_model('Samll_sample_face_reco_algorithm_siamese_best_val_acc.pt')

test_loader = generate_test_loader()
# Out:
# Model loaded from <== ./gdrive/MyDrive/Datasets/Samll_sample_face_reco_algorithm_siamese_best_val_acc.pt

# %%
train_accuracies= find_threshold(train_loader , thresholds, load_model)
# Out:
# Loading results...
# Finished loading results...
# starting with threshold:  0.0
# finished with threshold:  0.0
# starting with threshold:  0.01
# finished with threshold:  0.01
# starting with threshold:  0.02
# finished with threshold:  0.02
# starting with threshold:  0.03
# finished with threshold:  0.03
# starting with threshold:  0.04
# finished with threshold:  0.04
# starting with threshold:  0.05
# finished with threshold:  0.05
# starting with threshold:  0.06
# finished with threshold:  0.06
# starting with threshold:  0.07
# finished with threshold:  0.07
# starting with threshold:  0.08
# finished with threshold:  0.08
# starting with threshold:  0.09
# finished with threshold:  0.09
# starting with threshold:  0.1
# finished with threshold:  0.1
# starting with threshold:  0.11
# finished with threshold:  0.11
# starting with threshold:  0.12
# finished with threshold:  0.12
# starting with threshold:  0.13
# finished with threshold:  0.13
# starting with threshold:  0.14
# finished with threshold:  0.14
# starting with threshold:  0.15
# finished with threshold:  0.15
# starting with threshold:  0.16
# finished with threshold:  0.16
# starting with threshold:  0.17
# finished with threshold:  0.17
# starting with threshold:  0.18
# finished with threshold:  0.18
# starting with threshold:  0.19
# finished with threshold:  0.19
# starting with threshold:  0.2
# finished with threshold:  0.2
# starting with threshold:  0.21
# finished with threshold:  0.21
# starting with threshold:  0.22
# finished with threshold:  0.22
# starting with threshold:  0.23
# finished with threshold:  0.23
# starting with threshold:  0.24
# finished with threshold:  0.24
# starting with threshold:  0.25
# finished with threshold:  0.25
# starting with threshold:  0.26
# finished with threshold:  0.26
# starting with threshold:  0.27
# finished with threshold:  0.27
# starting with threshold:  0.28
# finished with threshold:  0.28
# starting with threshold:  0.29
# finished with threshold:  0.29
# starting with threshold:  0.3
# finished with threshold:  0.3
# starting with threshold:  0.31
# finished with threshold:  0.31
# starting with threshold:  0.32
# finished with threshold:  0.32
# starting with threshold:  0.33
# finished with threshold:  0.33
# starting with threshold:  0.34
# finished with threshold:  0.34
# starting with threshold:  0.35000000000000003
# finished with threshold:  0.35000000000000003
# starting with threshold:  0.36
# finished with threshold:  0.36
# starting with threshold:  0.37
# finished with threshold:  0.37
# starting with threshold:  0.38
# finished with threshold:  0.38
# starting with threshold:  0.39
# finished with threshold:  0.39
# starting with threshold:  0.4
# finished with threshold:  0.4
# starting with threshold:  0.41000000000000003
# finished with threshold:  0.41000000000000003
# starting with threshold:  0.42
# finished with threshold:  0.42
# starting with threshold:  0.43
# finished with threshold:  0.43
# starting with threshold:  0.44
# finished with threshold:  0.44
# starting with threshold:  0.45
# finished with threshold:  0.45
# starting with threshold:  0.46
# finished with threshold:  0.46
# starting with threshold:  0.47000000000000003
# finished with threshold:  0.47000000000000003
# starting with threshold:  0.48
# finished with threshold:  0.48
# starting with threshold:  0.49
# finished with threshold:  0.49
# starting with threshold:  0.5
# finished with threshold:  0.5
# starting with threshold:  0.51
# finished with threshold:  0.51
# starting with threshold:  0.52
# finished with threshold:  0.52
# starting with threshold:  0.53
# finished with threshold:  0.53
# starting with threshold:  0.54
# finished with threshold:  0.54
# starting with threshold:  0.55
# finished with threshold:  0.55
# starting with threshold:  0.56
# finished with threshold:  0.56
# starting with threshold:  0.5700000000000001
# finished with threshold:  0.5700000000000001
# starting with threshold:  0.58
# finished with threshold:  0.58
# starting with threshold:  0.59
# finished with threshold:  0.59
# starting with threshold:  0.6
# finished with threshold:  0.6
# starting with threshold:  0.61
# finished with threshold:  0.61
# starting with threshold:  0.62
# finished with threshold:  0.62
# starting with threshold:  0.63
# finished with threshold:  0.63
# starting with threshold:  0.64
# finished with threshold:  0.64
# starting with threshold:  0.65
# finished with threshold:  0.65
# starting with threshold:  0.66
# finished with threshold:  0.66
# starting with threshold:  0.67
# finished with threshold:  0.67
# starting with threshold:  0.68
# finished with threshold:  0.68
# starting with threshold:  0.6900000000000001
# finished with threshold:  0.6900000000000001
# starting with threshold:  0.7000000000000001
# finished with threshold:  0.7000000000000001
# starting with threshold:  0.71
# finished with threshold:  0.71
# starting with threshold:  0.72
# finished with threshold:  0.72
# starting with threshold:  0.73
# finished with threshold:  0.73
# starting with threshold:  0.74
# finished with threshold:  0.74
# starting with threshold:  0.75
# finished with threshold:  0.75
# starting with threshold:  0.76
# finished with threshold:  0.76
# starting with threshold:  0.77
# finished with threshold:  0.77
# starting with threshold:  0.78
# finished with threshold:  0.78
# starting with threshold:  0.79
# finished with threshold:  0.79
# starting with threshold:  0.8
# finished with threshold:  0.8
# starting with threshold:  0.81
# finished with threshold:  0.81
# starting with threshold:  0.8200000000000001
# finished with threshold:  0.8200000000000001
# starting with threshold:  0.8300000000000001
# finished with threshold:  0.8300000000000001
# starting with threshold:  0.84
# finished with threshold:  0.84
# starting with threshold:  0.85
# finished with threshold:  0.85
# starting with threshold:  0.86
# finished with threshold:  0.86
# starting with threshold:  0.87
# finished with threshold:  0.87
# starting with threshold:  0.88
# finished with threshold:  0.88
# starting with threshold:  0.89
# finished with threshold:  0.89
# starting with threshold:  0.9
# finished with threshold:  0.9
# starting with threshold:  0.91
# finished with threshold:  0.91
# starting with threshold:  0.92
# finished with threshold:  0.92
# starting with threshold:  0.93
# finished with threshold:  0.93
# starting with threshold:  0.9400000000000001
# finished with threshold:  0.9400000000000001
# starting with threshold:  0.9500000000000001
# finished with threshold:  0.9500000000000001
# starting with threshold:  0.96
# finished with threshold:  0.96
# starting with threshold:  0.97
# finished with threshold:  0.97
# starting with threshold:  0.98
# finished with threshold:  0.98
# starting with threshold:  0.99
# finished with threshold:  0.99
# starting with threshold:  1.0
# finished with threshold:  1.0
# starting with threshold:  1.01
# finished with threshold:  1.01
# starting with threshold:  1.02
# finished with threshold:  1.02
# starting with threshold:  1.03
# finished with threshold:  1.03
# starting with threshold:  1.04
# finished with threshold:  1.04
# starting with threshold:  1.05
# finished with threshold:  1.05
# starting with threshold:  1.06
# finished with threshold:  1.06
# starting with threshold:  1.07
# finished with threshold:  1.07
# starting with threshold:  1.08
# finished with threshold:  1.08
# starting with threshold:  1.09
# finished with threshold:  1.09
# starting with threshold:  1.1
# finished with threshold:  1.1
# starting with threshold:  1.11
# finished with threshold:  1.11
# starting with threshold:  1.12
# finished with threshold:  1.12
# starting with threshold:  1.1300000000000001
# finished with threshold:  1.1300000000000001
# starting with threshold:  1.1400000000000001
# finished with threshold:  1.1400000000000001
# starting with threshold:  1.1500000000000001
# finished with threshold:  1.1500000000000001
# starting with threshold:  1.16
# finished with threshold:  1.16
# starting with threshold:  1.17
# finished with threshold:  1.17
# starting with threshold:  1.18
# finished with threshold:  1.18
# starting with threshold:  1.19
# finished with threshold:  1.19
# starting with threshold:  1.2
# finished with threshold:  1.2
# starting with threshold:  1.21
# finished with threshold:  1.21
# starting with threshold:  1.22
# finished with threshold:  1.22
# starting with threshold:  1.23
# finished with threshold:  1.23
# starting with threshold:  1.24
# finished with threshold:  1.24
# starting with threshold:  1.25
# finished with threshold:  1.25
# starting with threshold:  1.26
# finished with threshold:  1.26
# starting with threshold:  1.27
# finished with threshold:  1.27
# starting with threshold:  1.28
# finished with threshold:  1.28
# starting with threshold:  1.29
# finished with threshold:  1.29
# starting with threshold:  1.3
# finished with threshold:  1.3
# starting with threshold:  1.31
# finished with threshold:  1.31
# starting with threshold:  1.32
# finished with threshold:  1.32
# starting with threshold:  1.33
# finished with threshold:  1.33
# starting with threshold:  1.34
# finished with threshold:  1.34
# starting with threshold:  1.35
# finished with threshold:  1.35
# starting with threshold:  1.36
# finished with threshold:  1.36
# starting with threshold:  1.37
# finished with threshold:  1.37
# starting with threshold:  1.3800000000000001
# finished with threshold:  1.3800000000000001
# starting with threshold:  1.3900000000000001
# finished with threshold:  1.3900000000000001
# starting with threshold:  1.4000000000000001
# finished with threshold:  1.4000000000000001
# starting with threshold:  1.41
# finished with threshold:  1.41
# starting with threshold:  1.42
# finished with threshold:  1.42
# starting with threshold:  1.43
# finished with threshold:  1.43
# starting with threshold:  1.44
# finished with threshold:  1.44
# starting with threshold:  1.45
# finished with threshold:  1.45
# starting with threshold:  1.46
# finished with threshold:  1.46
# starting with threshold:  1.47
# finished with threshold:  1.47
# starting with threshold:  1.48
# finished with threshold:  1.48
# starting with threshold:  1.49
# finished with threshold:  1.49
# starting with threshold:  1.5
# finished with threshold:  1.5
# starting with threshold:  1.51
# finished with threshold:  1.51
# starting with threshold:  1.52
# finished with threshold:  1.52
# starting with threshold:  1.53
# finished with threshold:  1.53
# starting with threshold:  1.54
# finished with threshold:  1.54
# starting with threshold:  1.55
# finished with threshold:  1.55
# starting with threshold:  1.56
# finished with threshold:  1.56
# starting with threshold:  1.57
# finished with threshold:  1.57
# starting with threshold:  1.58
# finished with threshold:  1.58
# starting with threshold:  1.59
# finished with threshold:  1.59
# starting with threshold:  1.6
# finished with threshold:  1.6
# starting with threshold:  1.61
# finished with threshold:  1.61
# starting with threshold:  1.62
# finished with threshold:  1.62
# starting with threshold:  1.6300000000000001
# finished with threshold:  1.6300000000000001
# starting with threshold:  1.6400000000000001
# finished with threshold:  1.6400000000000001
# starting with threshold:  1.6500000000000001
# finished with threshold:  1.6500000000000001
# starting with threshold:  1.6600000000000001
# finished with threshold:  1.6600000000000001
# starting with threshold:  1.67
# finished with threshold:  1.67
# starting with threshold:  1.68
# finished with threshold:  1.68
# starting with threshold:  1.69
# finished with threshold:  1.69
# starting with threshold:  1.7
# finished with threshold:  1.7
# starting with threshold:  1.71
# finished with threshold:  1.71
# starting with threshold:  1.72
# finished with threshold:  1.72
# starting with threshold:  1.73
# finished with threshold:  1.73
# starting with threshold:  1.74
# finished with threshold:  1.74
# starting with threshold:  1.75
# finished with threshold:  1.75
# starting with threshold:  1.76
# finished with threshold:  1.76
# starting with threshold:  1.77
# finished with threshold:  1.77
# starting with threshold:  1.78
# finished with threshold:  1.78
# starting with threshold:  1.79
# finished with threshold:  1.79
# starting with threshold:  1.8
# finished with threshold:  1.8
# starting with threshold:  1.81
# finished with threshold:  1.81
# starting with threshold:  1.82
# finished with threshold:  1.82
# starting with threshold:  1.83
# finished with threshold:  1.83
# starting with threshold:  1.84
# finished with threshold:  1.84
# starting with threshold:  1.85
# finished with threshold:  1.85
# starting with threshold:  1.86
# finished with threshold:  1.86
# starting with threshold:  1.87
# finished with threshold:  1.87
# starting with threshold:  1.8800000000000001
# finished with threshold:  1.8800000000000001
# starting with threshold:  1.8900000000000001
# finished with threshold:  1.8900000000000001
# starting with threshold:  1.9000000000000001
# finished with threshold:  1.9000000000000001
# starting with threshold:  1.9100000000000001
# finished with threshold:  1.9100000000000001
# starting with threshold:  1.92
# finished with threshold:  1.92
# starting with threshold:  1.93
# finished with threshold:  1.93
# starting with threshold:  1.94
# finished with threshold:  1.94
# starting with threshold:  1.95
# finished with threshold:  1.95
# starting with threshold:  1.96
# finished with threshold:  1.96
# starting with threshold:  1.97
# finished with threshold:  1.97
# starting with threshold:  1.98
# finished with threshold:  1.98
# starting with threshold:  1.99
# finished with threshold:  1.99

# %%
test_accuracies= find_threshold(test_loader,thresholds, load_model)
# Out:
# Loading results...
# Finished loading results...
# starting with threshold:  0.0
# finished with threshold:  0.0
# starting with threshold:  0.01
# finished with threshold:  0.01
# starting with threshold:  0.02
# finished with threshold:  0.02
# starting with threshold:  0.03
# finished with threshold:  0.03
# starting with threshold:  0.04
# finished with threshold:  0.04
# starting with threshold:  0.05
# finished with threshold:  0.05
# starting with threshold:  0.06
# finished with threshold:  0.06
# starting with threshold:  0.07
# finished with threshold:  0.07
# starting with threshold:  0.08
# finished with threshold:  0.08
# starting with threshold:  0.09
# finished with threshold:  0.09
# starting with threshold:  0.1
# finished with threshold:  0.1
# starting with threshold:  0.11
# finished with threshold:  0.11
# starting with threshold:  0.12
# finished with threshold:  0.12
# starting with threshold:  0.13
# finished with threshold:  0.13
# starting with threshold:  0.14
# finished with threshold:  0.14
# starting with threshold:  0.15
# finished with threshold:  0.15
# starting with threshold:  0.16
# finished with threshold:  0.16
# starting with threshold:  0.17
# finished with threshold:  0.17
# starting with threshold:  0.18
# finished with threshold:  0.18
# starting with threshold:  0.19
# finished with threshold:  0.19
# starting with threshold:  0.2
# finished with threshold:  0.2
# starting with threshold:  0.21
# finished with threshold:  0.21
# starting with threshold:  0.22
# finished with threshold:  0.22
# starting with threshold:  0.23
# finished with threshold:  0.23
# starting with threshold:  0.24
# finished with threshold:  0.24
# starting with threshold:  0.25
# finished with threshold:  0.25
# starting with threshold:  0.26
# finished with threshold:  0.26
# starting with threshold:  0.27
# finished with threshold:  0.27
# starting with threshold:  0.28
# finished with threshold:  0.28
# starting with threshold:  0.29
# finished with threshold:  0.29
# starting with threshold:  0.3
# finished with threshold:  0.3
# starting with threshold:  0.31
# finished with threshold:  0.31
# starting with threshold:  0.32
# finished with threshold:  0.32
# starting with threshold:  0.33
# finished with threshold:  0.33
# starting with threshold:  0.34
# finished with threshold:  0.34
# starting with threshold:  0.35000000000000003
# finished with threshold:  0.35000000000000003
# starting with threshold:  0.36
# finished with threshold:  0.36
# starting with threshold:  0.37
# finished with threshold:  0.37
# starting with threshold:  0.38
# finished with threshold:  0.38
# starting with threshold:  0.39
# finished with threshold:  0.39
# starting with threshold:  0.4
# finished with threshold:  0.4
# starting with threshold:  0.41000000000000003
# finished with threshold:  0.41000000000000003
# starting with threshold:  0.42
# finished with threshold:  0.42
# starting with threshold:  0.43
# finished with threshold:  0.43
# starting with threshold:  0.44
# finished with threshold:  0.44
# starting with threshold:  0.45
# finished with threshold:  0.45
# starting with threshold:  0.46
# finished with threshold:  0.46
# starting with threshold:  0.47000000000000003
# finished with threshold:  0.47000000000000003
# starting with threshold:  0.48
# finished with threshold:  0.48
# starting with threshold:  0.49
# finished with threshold:  0.49
# starting with threshold:  0.5
# finished with threshold:  0.5
# starting with threshold:  0.51
# finished with threshold:  0.51
# starting with threshold:  0.52
# finished with threshold:  0.52
# starting with threshold:  0.53
# finished with threshold:  0.53
# starting with threshold:  0.54
# finished with threshold:  0.54
# starting with threshold:  0.55
# finished with threshold:  0.55
# starting with threshold:  0.56
# finished with threshold:  0.56
# starting with threshold:  0.5700000000000001
# finished with threshold:  0.5700000000000001
# starting with threshold:  0.58
# finished with threshold:  0.58
# starting with threshold:  0.59
# finished with threshold:  0.59
# starting with threshold:  0.6
# finished with threshold:  0.6
# starting with threshold:  0.61
# finished with threshold:  0.61
# starting with threshold:  0.62
# finished with threshold:  0.62
# starting with threshold:  0.63
# finished with threshold:  0.63
# starting with threshold:  0.64
# finished with threshold:  0.64
# starting with threshold:  0.65
# finished with threshold:  0.65
# starting with threshold:  0.66
# finished with threshold:  0.66
# starting with threshold:  0.67
# finished with threshold:  0.67
# starting with threshold:  0.68
# finished with threshold:  0.68
# starting with threshold:  0.6900000000000001
# finished with threshold:  0.6900000000000001
# starting with threshold:  0.7000000000000001
# finished with threshold:  0.7000000000000001
# starting with threshold:  0.71
# finished with threshold:  0.71
# starting with threshold:  0.72
# finished with threshold:  0.72
# starting with threshold:  0.73
# finished with threshold:  0.73
# starting with threshold:  0.74
# finished with threshold:  0.74
# starting with threshold:  0.75
# finished with threshold:  0.75
# starting with threshold:  0.76
# finished with threshold:  0.76
# starting with threshold:  0.77
# finished with threshold:  0.77
# starting with threshold:  0.78
# finished with threshold:  0.78
# starting with threshold:  0.79
# finished with threshold:  0.79
# starting with threshold:  0.8
# finished with threshold:  0.8
# starting with threshold:  0.81
# finished with threshold:  0.81
# starting with threshold:  0.8200000000000001
# finished with threshold:  0.8200000000000001
# starting with threshold:  0.8300000000000001
# finished with threshold:  0.8300000000000001
# starting with threshold:  0.84
# finished with threshold:  0.84
# starting with threshold:  0.85
# finished with threshold:  0.85
# starting with threshold:  0.86
# finished with threshold:  0.86
# starting with threshold:  0.87
# finished with threshold:  0.87
# starting with threshold:  0.88
# finished with threshold:  0.88
# starting with threshold:  0.89
# finished with threshold:  0.89
# starting with threshold:  0.9
# finished with threshold:  0.9
# starting with threshold:  0.91
# finished with threshold:  0.91
# starting with threshold:  0.92
# finished with threshold:  0.92
# starting with threshold:  0.93
# finished with threshold:  0.93
# starting with threshold:  0.9400000000000001
# finished with threshold:  0.9400000000000001
# starting with threshold:  0.9500000000000001
# finished with threshold:  0.9500000000000001
# starting with threshold:  0.96
# finished with threshold:  0.96
# starting with threshold:  0.97
# finished with threshold:  0.97
# starting with threshold:  0.98
# finished with threshold:  0.98
# starting with threshold:  0.99
# finished with threshold:  0.99
# starting with threshold:  1.0
# finished with threshold:  1.0
# starting with threshold:  1.01
# finished with threshold:  1.01
# starting with threshold:  1.02
# finished with threshold:  1.02
# starting with threshold:  1.03
# finished with threshold:  1.03
# starting with threshold:  1.04
# finished with threshold:  1.04
# starting with threshold:  1.05
# finished with threshold:  1.05
# starting with threshold:  1.06
# finished with threshold:  1.06
# starting with threshold:  1.07
# finished with threshold:  1.07
# starting with threshold:  1.08
# finished with threshold:  1.08
# starting with threshold:  1.09
# finished with threshold:  1.09
# starting with threshold:  1.1
# finished with threshold:  1.1
# starting with threshold:  1.11
# finished with threshold:  1.11
# starting with threshold:  1.12
# finished with threshold:  1.12
# starting with threshold:  1.1300000000000001
# finished with threshold:  1.1300000000000001
# starting with threshold:  1.1400000000000001
# finished with threshold:  1.1400000000000001
# starting with threshold:  1.1500000000000001
# finished with threshold:  1.1500000000000001
# starting with threshold:  1.16
# finished with threshold:  1.16
# starting with threshold:  1.17
# finished with threshold:  1.17
# starting with threshold:  1.18
# finished with threshold:  1.18
# starting with threshold:  1.19
# finished with threshold:  1.19
# starting with threshold:  1.2
# finished with threshold:  1.2
# starting with threshold:  1.21
# finished with threshold:  1.21
# starting with threshold:  1.22
# finished with threshold:  1.22
# starting with threshold:  1.23
# finished with threshold:  1.23
# starting with threshold:  1.24
# finished with threshold:  1.24
# starting with threshold:  1.25
# finished with threshold:  1.25
# starting with threshold:  1.26
# finished with threshold:  1.26
# starting with threshold:  1.27
# finished with threshold:  1.27
# starting with threshold:  1.28
# finished with threshold:  1.28
# starting with threshold:  1.29
# finished with threshold:  1.29
# starting with threshold:  1.3
# finished with threshold:  1.3
# starting with threshold:  1.31
# finished with threshold:  1.31
# starting with threshold:  1.32
# finished with threshold:  1.32
# starting with threshold:  1.33
# finished with threshold:  1.33
# starting with threshold:  1.34
# finished with threshold:  1.34
# starting with threshold:  1.35
# finished with threshold:  1.35
# starting with threshold:  1.36
# finished with threshold:  1.36
# starting with threshold:  1.37
# finished with threshold:  1.37
# starting with threshold:  1.3800000000000001
# finished with threshold:  1.3800000000000001
# starting with threshold:  1.3900000000000001
# finished with threshold:  1.3900000000000001
# starting with threshold:  1.4000000000000001
# finished with threshold:  1.4000000000000001
# starting with threshold:  1.41
# finished with threshold:  1.41
# starting with threshold:  1.42
# finished with threshold:  1.42
# starting with threshold:  1.43
# finished with threshold:  1.43
# starting with threshold:  1.44
# finished with threshold:  1.44
# starting with threshold:  1.45
# finished with threshold:  1.45
# starting with threshold:  1.46
# finished with threshold:  1.46
# starting with threshold:  1.47
# finished with threshold:  1.47
# starting with threshold:  1.48
# finished with threshold:  1.48
# starting with threshold:  1.49
# finished with threshold:  1.49
# starting with threshold:  1.5
# finished with threshold:  1.5
# starting with threshold:  1.51
# finished with threshold:  1.51
# starting with threshold:  1.52
# finished with threshold:  1.52
# starting with threshold:  1.53
# finished with threshold:  1.53
# starting with threshold:  1.54
# finished with threshold:  1.54
# starting with threshold:  1.55
# finished with threshold:  1.55
# starting with threshold:  1.56
# finished with threshold:  1.56
# starting with threshold:  1.57
# finished with threshold:  1.57
# starting with threshold:  1.58
# finished with threshold:  1.58
# starting with threshold:  1.59
# finished with threshold:  1.59
# starting with threshold:  1.6
# finished with threshold:  1.6
# starting with threshold:  1.61
# finished with threshold:  1.61
# starting with threshold:  1.62
# finished with threshold:  1.62
# starting with threshold:  1.6300000000000001
# finished with threshold:  1.6300000000000001
# starting with threshold:  1.6400000000000001
# finished with threshold:  1.6400000000000001
# starting with threshold:  1.6500000000000001
# finished with threshold:  1.6500000000000001
# starting with threshold:  1.6600000000000001
# finished with threshold:  1.6600000000000001
# starting with threshold:  1.67
# finished with threshold:  1.67
# starting with threshold:  1.68
# finished with threshold:  1.68
# starting with threshold:  1.69
# finished with threshold:  1.69
# starting with threshold:  1.7
# finished with threshold:  1.7
# starting with threshold:  1.71
# finished with threshold:  1.71
# starting with threshold:  1.72
# finished with threshold:  1.72
# starting with threshold:  1.73
# finished with threshold:  1.73
# starting with threshold:  1.74
# finished with threshold:  1.74
# starting with threshold:  1.75
# finished with threshold:  1.75
# starting with threshold:  1.76
# finished with threshold:  1.76
# starting with threshold:  1.77
# finished with threshold:  1.77
# starting with threshold:  1.78
# finished with threshold:  1.78
# starting with threshold:  1.79
# finished with threshold:  1.79
# starting with threshold:  1.8
# finished with threshold:  1.8
# starting with threshold:  1.81
# finished with threshold:  1.81
# starting with threshold:  1.82
# finished with threshold:  1.82
# starting with threshold:  1.83
# finished with threshold:  1.83
# starting with threshold:  1.84
# finished with threshold:  1.84
# starting with threshold:  1.85
# finished with threshold:  1.85
# starting with threshold:  1.86
# finished with threshold:  1.86
# starting with threshold:  1.87
# finished with threshold:  1.87
# starting with threshold:  1.8800000000000001
# finished with threshold:  1.8800000000000001
# starting with threshold:  1.8900000000000001
# finished with threshold:  1.8900000000000001
# starting with threshold:  1.9000000000000001
# finished with threshold:  1.9000000000000001
# starting with threshold:  1.9100000000000001
# finished with threshold:  1.9100000000000001
# starting with threshold:  1.92
# finished with threshold:  1.92
# starting with threshold:  1.93
# finished with threshold:  1.93
# starting with threshold:  1.94
# finished with threshold:  1.94
# starting with threshold:  1.95
# finished with threshold:  1.95
# starting with threshold:  1.96
# finished with threshold:  1.96
# starting with threshold:  1.97
# finished with threshold:  1.97
# starting with threshold:  1.98
# finished with threshold:  1.98
# starting with threshold:  1.99
# finished with threshold:  1.99

# %%
mx_train_acc, train_threshold = find_max_accuracies(thresholds, train_accuracies, 'train' )
mx_test_acc, test_threshold = find_max_accuracies(thresholds, test_accuracies, 'test' )

plot_x_y('Accuracy',thresholds,train_accuracies,'Train accuracy')
plot_x_y('Accuracy',thresholds,test_accuracies,'Test accuracy')
# Out:
# Max  train  acc:  0.6119318181818182            Threshold:  0.51
# Max  test  acc:  0.611            Threshold:  0.49

# %% [markdown]
# Longest trained model

# %%
load_model, load_optimizer= Load_saved_model('Samll_sample_face_reco_algorithm_siamese_longest_trained.pt')

test_loader = generate_test_loader()
# Out:
# Model loaded from <== ./gdrive/MyDrive/Datasets/Samll_sample_face_reco_algorithm_siamese_longest_trained.pt

# %%
train_accuracies= find_threshold(train_loader , thresholds, load_model)
# Out:
# Loading results...
# Finished loading results...
# starting with threshold:  0.0
# finished with threshold:  0.0
# starting with threshold:  0.01
# finished with threshold:  0.01
# starting with threshold:  0.02
# finished with threshold:  0.02
# starting with threshold:  0.03
# finished with threshold:  0.03
# starting with threshold:  0.04
# finished with threshold:  0.04
# starting with threshold:  0.05
# finished with threshold:  0.05
# starting with threshold:  0.06
# finished with threshold:  0.06
# starting with threshold:  0.07
# finished with threshold:  0.07
# starting with threshold:  0.08
# finished with threshold:  0.08
# starting with threshold:  0.09
# finished with threshold:  0.09
# starting with threshold:  0.1
# finished with threshold:  0.1
# starting with threshold:  0.11
# finished with threshold:  0.11
# starting with threshold:  0.12
# finished with threshold:  0.12
# starting with threshold:  0.13
# finished with threshold:  0.13
# starting with threshold:  0.14
# finished with threshold:  0.14
# starting with threshold:  0.15
# finished with threshold:  0.15
# starting with threshold:  0.16
# finished with threshold:  0.16
# starting with threshold:  0.17
# finished with threshold:  0.17
# starting with threshold:  0.18
# finished with threshold:  0.18
# starting with threshold:  0.19
# finished with threshold:  0.19
# starting with threshold:  0.2
# finished with threshold:  0.2
# starting with threshold:  0.21
# finished with threshold:  0.21
# starting with threshold:  0.22
# finished with threshold:  0.22
# starting with threshold:  0.23
# finished with threshold:  0.23
# starting with threshold:  0.24
# finished with threshold:  0.24
# starting with threshold:  0.25
# finished with threshold:  0.25
# starting with threshold:  0.26
# finished with threshold:  0.26
# starting with threshold:  0.27
# finished with threshold:  0.27
# starting with threshold:  0.28
# finished with threshold:  0.28
# starting with threshold:  0.29
# finished with threshold:  0.29
# starting with threshold:  0.3
# finished with threshold:  0.3
# starting with threshold:  0.31
# finished with threshold:  0.31
# starting with threshold:  0.32
# finished with threshold:  0.32
# starting with threshold:  0.33
# finished with threshold:  0.33
# starting with threshold:  0.34
# finished with threshold:  0.34
# starting with threshold:  0.35000000000000003
# finished with threshold:  0.35000000000000003
# starting with threshold:  0.36
# finished with threshold:  0.36
# starting with threshold:  0.37
# finished with threshold:  0.37
# starting with threshold:  0.38
# finished with threshold:  0.38
# starting with threshold:  0.39
# finished with threshold:  0.39
# starting with threshold:  0.4
# finished with threshold:  0.4
# starting with threshold:  0.41000000000000003
# finished with threshold:  0.41000000000000003
# starting with threshold:  0.42
# finished with threshold:  0.42
# starting with threshold:  0.43
# finished with threshold:  0.43
# starting with threshold:  0.44
# finished with threshold:  0.44
# starting with threshold:  0.45
# finished with threshold:  0.45
# starting with threshold:  0.46
# finished with threshold:  0.46
# starting with threshold:  0.47000000000000003
# finished with threshold:  0.47000000000000003
# starting with threshold:  0.48
# finished with threshold:  0.48
# starting with threshold:  0.49
# finished with threshold:  0.49
# starting with threshold:  0.5
# finished with threshold:  0.5
# starting with threshold:  0.51
# finished with threshold:  0.51
# starting with threshold:  0.52
# finished with threshold:  0.52
# starting with threshold:  0.53
# finished with threshold:  0.53
# starting with threshold:  0.54
# finished with threshold:  0.54
# starting with threshold:  0.55
# finished with threshold:  0.55
# starting with threshold:  0.56
# finished with threshold:  0.56
# starting with threshold:  0.5700000000000001
# finished with threshold:  0.5700000000000001
# starting with threshold:  0.58
# finished with threshold:  0.58
# starting with threshold:  0.59
# finished with threshold:  0.59
# starting with threshold:  0.6
# finished with threshold:  0.6
# starting with threshold:  0.61
# finished with threshold:  0.61
# starting with threshold:  0.62
# finished with threshold:  0.62
# starting with threshold:  0.63
# finished with threshold:  0.63
# starting with threshold:  0.64
# finished with threshold:  0.64
# starting with threshold:  0.65
# finished with threshold:  0.65
# starting with threshold:  0.66
# finished with threshold:  0.66
# starting with threshold:  0.67
# finished with threshold:  0.67
# starting with threshold:  0.68
# finished with threshold:  0.68
# starting with threshold:  0.6900000000000001
# finished with threshold:  0.6900000000000001
# starting with threshold:  0.7000000000000001
# finished with threshold:  0.7000000000000001
# starting with threshold:  0.71
# finished with threshold:  0.71
# starting with threshold:  0.72
# finished with threshold:  0.72
# starting with threshold:  0.73
# finished with threshold:  0.73
# starting with threshold:  0.74
# finished with threshold:  0.74
# starting with threshold:  0.75
# finished with threshold:  0.75
# starting with threshold:  0.76
# finished with threshold:  0.76
# starting with threshold:  0.77
# finished with threshold:  0.77
# starting with threshold:  0.78
# finished with threshold:  0.78
# starting with threshold:  0.79
# finished with threshold:  0.79
# starting with threshold:  0.8
# finished with threshold:  0.8
# starting with threshold:  0.81
# finished with threshold:  0.81
# starting with threshold:  0.8200000000000001
# finished with threshold:  0.8200000000000001
# starting with threshold:  0.8300000000000001
# finished with threshold:  0.8300000000000001
# starting with threshold:  0.84
# finished with threshold:  0.84
# starting with threshold:  0.85
# finished with threshold:  0.85
# starting with threshold:  0.86
# finished with threshold:  0.86
# starting with threshold:  0.87
# finished with threshold:  0.87
# starting with threshold:  0.88
# finished with threshold:  0.88
# starting with threshold:  0.89
# finished with threshold:  0.89
# starting with threshold:  0.9
# finished with threshold:  0.9
# starting with threshold:  0.91
# finished with threshold:  0.91
# starting with threshold:  0.92
# finished with threshold:  0.92
# starting with threshold:  0.93
# finished with threshold:  0.93
# starting with threshold:  0.9400000000000001
# finished with threshold:  0.9400000000000001
# starting with threshold:  0.9500000000000001
# finished with threshold:  0.9500000000000001
# starting with threshold:  0.96
# finished with threshold:  0.96
# starting with threshold:  0.97
# finished with threshold:  0.97
# starting with threshold:  0.98
# finished with threshold:  0.98
# starting with threshold:  0.99
# finished with threshold:  0.99
# starting with threshold:  1.0
# finished with threshold:  1.0
# starting with threshold:  1.01
# finished with threshold:  1.01
# starting with threshold:  1.02
# finished with threshold:  1.02
# starting with threshold:  1.03
# finished with threshold:  1.03
# starting with threshold:  1.04
# finished with threshold:  1.04
# starting with threshold:  1.05
# finished with threshold:  1.05
# starting with threshold:  1.06
# finished with threshold:  1.06
# starting with threshold:  1.07
# finished with threshold:  1.07
# starting with threshold:  1.08
# finished with threshold:  1.08
# starting with threshold:  1.09
# finished with threshold:  1.09
# starting with threshold:  1.1
# finished with threshold:  1.1
# starting with threshold:  1.11
# finished with threshold:  1.11
# starting with threshold:  1.12
# finished with threshold:  1.12
# starting with threshold:  1.1300000000000001
# finished with threshold:  1.1300000000000001
# starting with threshold:  1.1400000000000001
# finished with threshold:  1.1400000000000001
# starting with threshold:  1.1500000000000001
# finished with threshold:  1.1500000000000001
# starting with threshold:  1.16
# finished with threshold:  1.16
# starting with threshold:  1.17
# finished with threshold:  1.17
# starting with threshold:  1.18
# finished with threshold:  1.18
# starting with threshold:  1.19
# finished with threshold:  1.19
# starting with threshold:  1.2
# finished with threshold:  1.2
# starting with threshold:  1.21
# finished with threshold:  1.21
# starting with threshold:  1.22
# finished with threshold:  1.22
# starting with threshold:  1.23
# finished with threshold:  1.23
# starting with threshold:  1.24
# finished with threshold:  1.24
# starting with threshold:  1.25
# finished with threshold:  1.25
# starting with threshold:  1.26
# finished with threshold:  1.26
# starting with threshold:  1.27
# finished with threshold:  1.27
# starting with threshold:  1.28
# finished with threshold:  1.28
# starting with threshold:  1.29
# finished with threshold:  1.29
# starting with threshold:  1.3
# finished with threshold:  1.3
# starting with threshold:  1.31
# finished with threshold:  1.31
# starting with threshold:  1.32
# finished with threshold:  1.32
# starting with threshold:  1.33
# finished with threshold:  1.33
# starting with threshold:  1.34
# finished with threshold:  1.34
# starting with threshold:  1.35
# finished with threshold:  1.35
# starting with threshold:  1.36
# finished with threshold:  1.36
# starting with threshold:  1.37
# finished with threshold:  1.37
# starting with threshold:  1.3800000000000001
# finished with threshold:  1.3800000000000001
# starting with threshold:  1.3900000000000001
# finished with threshold:  1.3900000000000001
# starting with threshold:  1.4000000000000001
# finished with threshold:  1.4000000000000001
# starting with threshold:  1.41
# finished with threshold:  1.41
# starting with threshold:  1.42
# finished with threshold:  1.42
# starting with threshold:  1.43
# finished with threshold:  1.43
# starting with threshold:  1.44
# finished with threshold:  1.44
# starting with threshold:  1.45
# finished with threshold:  1.45
# starting with threshold:  1.46
# finished with threshold:  1.46
# starting with threshold:  1.47
# finished with threshold:  1.47
# starting with threshold:  1.48
# finished with threshold:  1.48
# starting with threshold:  1.49
# finished with threshold:  1.49
# starting with threshold:  1.5
# finished with threshold:  1.5
# starting with threshold:  1.51
# finished with threshold:  1.51
# starting with threshold:  1.52
# finished with threshold:  1.52
# starting with threshold:  1.53
# finished with threshold:  1.53
# starting with threshold:  1.54
# finished with threshold:  1.54
# starting with threshold:  1.55
# finished with threshold:  1.55
# starting with threshold:  1.56
# finished with threshold:  1.56
# starting with threshold:  1.57
# finished with threshold:  1.57
# starting with threshold:  1.58
# finished with threshold:  1.58
# starting with threshold:  1.59
# finished with threshold:  1.59
# starting with threshold:  1.6
# finished with threshold:  1.6
# starting with threshold:  1.61
# finished with threshold:  1.61
# starting with threshold:  1.62
# finished with threshold:  1.62
# starting with threshold:  1.6300000000000001
# finished with threshold:  1.6300000000000001
# starting with threshold:  1.6400000000000001
# finished with threshold:  1.6400000000000001
# starting with threshold:  1.6500000000000001
# finished with threshold:  1.6500000000000001
# starting with threshold:  1.6600000000000001
# finished with threshold:  1.6600000000000001
# starting with threshold:  1.67
# finished with threshold:  1.67
# starting with threshold:  1.68
# finished with threshold:  1.68
# starting with threshold:  1.69
# finished with threshold:  1.69
# starting with threshold:  1.7
# finished with threshold:  1.7
# starting with threshold:  1.71
# finished with threshold:  1.71
# starting with threshold:  1.72
# finished with threshold:  1.72
# starting with threshold:  1.73
# finished with threshold:  1.73
# starting with threshold:  1.74
# finished with threshold:  1.74
# starting with threshold:  1.75
# finished with threshold:  1.75
# starting with threshold:  1.76
# finished with threshold:  1.76
# starting with threshold:  1.77
# finished with threshold:  1.77
# starting with threshold:  1.78
# finished with threshold:  1.78
# starting with threshold:  1.79
# finished with threshold:  1.79
# starting with threshold:  1.8
# finished with threshold:  1.8
# starting with threshold:  1.81
# finished with threshold:  1.81
# starting with threshold:  1.82
# finished with threshold:  1.82
# starting with threshold:  1.83
# finished with threshold:  1.83
# starting with threshold:  1.84
# finished with threshold:  1.84
# starting with threshold:  1.85
# finished with threshold:  1.85
# starting with threshold:  1.86
# finished with threshold:  1.86
# starting with threshold:  1.87
# finished with threshold:  1.87
# starting with threshold:  1.8800000000000001
# finished with threshold:  1.8800000000000001
# starting with threshold:  1.8900000000000001
# finished with threshold:  1.8900000000000001
# starting with threshold:  1.9000000000000001
# finished with threshold:  1.9000000000000001
# starting with threshold:  1.9100000000000001
# finished with threshold:  1.9100000000000001
# starting with threshold:  1.92
# finished with threshold:  1.92
# starting with threshold:  1.93
# finished with threshold:  1.93
# starting with threshold:  1.94
# finished with threshold:  1.94
# starting with threshold:  1.95
# finished with threshold:  1.95
# starting with threshold:  1.96
# finished with threshold:  1.96
# starting with threshold:  1.97
# finished with threshold:  1.97
# starting with threshold:  1.98
# finished with threshold:  1.98
# starting with threshold:  1.99
# finished with threshold:  1.99

# %%
test_accuracies= find_threshold(test_loader,thresholds, load_model)
# Out:
# Loading results...
# Finished loading results...
# starting with threshold:  0.0
# finished with threshold:  0.0
# starting with threshold:  0.01
# finished with threshold:  0.01
# starting with threshold:  0.02
# finished with threshold:  0.02
# starting with threshold:  0.03
# finished with threshold:  0.03
# starting with threshold:  0.04
# finished with threshold:  0.04
# starting with threshold:  0.05
# finished with threshold:  0.05
# starting with threshold:  0.06
# finished with threshold:  0.06
# starting with threshold:  0.07
# finished with threshold:  0.07
# starting with threshold:  0.08
# finished with threshold:  0.08
# starting with threshold:  0.09
# finished with threshold:  0.09
# starting with threshold:  0.1
# finished with threshold:  0.1
# starting with threshold:  0.11
# finished with threshold:  0.11
# starting with threshold:  0.12
# finished with threshold:  0.12
# starting with threshold:  0.13
# finished with threshold:  0.13
# starting with threshold:  0.14
# finished with threshold:  0.14
# starting with threshold:  0.15
# finished with threshold:  0.15
# starting with threshold:  0.16
# finished with threshold:  0.16
# starting with threshold:  0.17
# finished with threshold:  0.17
# starting with threshold:  0.18
# finished with threshold:  0.18
# starting with threshold:  0.19
# finished with threshold:  0.19
# starting with threshold:  0.2
# finished with threshold:  0.2
# starting with threshold:  0.21
# finished with threshold:  0.21
# starting with threshold:  0.22
# finished with threshold:  0.22
# starting with threshold:  0.23
# finished with threshold:  0.23
# starting with threshold:  0.24
# finished with threshold:  0.24
# starting with threshold:  0.25
# finished with threshold:  0.25
# starting with threshold:  0.26
# finished with threshold:  0.26
# starting with threshold:  0.27
# finished with threshold:  0.27
# starting with threshold:  0.28
# finished with threshold:  0.28
# starting with threshold:  0.29
# finished with threshold:  0.29
# starting with threshold:  0.3
# finished with threshold:  0.3
# starting with threshold:  0.31
# finished with threshold:  0.31
# starting with threshold:  0.32
# finished with threshold:  0.32
# starting with threshold:  0.33
# finished with threshold:  0.33
# starting with threshold:  0.34
# finished with threshold:  0.34
# starting with threshold:  0.35000000000000003
# finished with threshold:  0.35000000000000003
# starting with threshold:  0.36
# finished with threshold:  0.36
# starting with threshold:  0.37
# finished with threshold:  0.37
# starting with threshold:  0.38
# finished with threshold:  0.38
# starting with threshold:  0.39
# finished with threshold:  0.39
# starting with threshold:  0.4
# finished with threshold:  0.4
# starting with threshold:  0.41000000000000003
# finished with threshold:  0.41000000000000003
# starting with threshold:  0.42
# finished with threshold:  0.42
# starting with threshold:  0.43
# finished with threshold:  0.43
# starting with threshold:  0.44
# finished with threshold:  0.44
# starting with threshold:  0.45
# finished with threshold:  0.45
# starting with threshold:  0.46
# finished with threshold:  0.46
# starting with threshold:  0.47000000000000003
# finished with threshold:  0.47000000000000003
# starting with threshold:  0.48
# finished with threshold:  0.48
# starting with threshold:  0.49
# finished with threshold:  0.49
# starting with threshold:  0.5
# finished with threshold:  0.5
# starting with threshold:  0.51
# finished with threshold:  0.51
# starting with threshold:  0.52
# finished with threshold:  0.52
# starting with threshold:  0.53
# finished with threshold:  0.53
# starting with threshold:  0.54
# finished with threshold:  0.54
# starting with threshold:  0.55
# finished with threshold:  0.55
# starting with threshold:  0.56
# finished with threshold:  0.56
# starting with threshold:  0.5700000000000001
# finished with threshold:  0.5700000000000001
# starting with threshold:  0.58
# finished with threshold:  0.58
# starting with threshold:  0.59
# finished with threshold:  0.59
# starting with threshold:  0.6
# finished with threshold:  0.6
# starting with threshold:  0.61
# finished with threshold:  0.61
# starting with threshold:  0.62
# finished with threshold:  0.62
# starting with threshold:  0.63
# finished with threshold:  0.63
# starting with threshold:  0.64
# finished with threshold:  0.64
# starting with threshold:  0.65
# finished with threshold:  0.65
# starting with threshold:  0.66
# finished with threshold:  0.66
# starting with threshold:  0.67
# finished with threshold:  0.67
# starting with threshold:  0.68
# finished with threshold:  0.68
# starting with threshold:  0.6900000000000001
# finished with threshold:  0.6900000000000001
# starting with threshold:  0.7000000000000001
# finished with threshold:  0.7000000000000001
# starting with threshold:  0.71
# finished with threshold:  0.71
# starting with threshold:  0.72
# finished with threshold:  0.72
# starting with threshold:  0.73
# finished with threshold:  0.73
# starting with threshold:  0.74
# finished with threshold:  0.74
# starting with threshold:  0.75
# finished with threshold:  0.75
# starting with threshold:  0.76
# finished with threshold:  0.76
# starting with threshold:  0.77
# finished with threshold:  0.77
# starting with threshold:  0.78
# finished with threshold:  0.78
# starting with threshold:  0.79
# finished with threshold:  0.79
# starting with threshold:  0.8
# finished with threshold:  0.8
# starting with threshold:  0.81
# finished with threshold:  0.81
# starting with threshold:  0.8200000000000001
# finished with threshold:  0.8200000000000001
# starting with threshold:  0.8300000000000001
# finished with threshold:  0.8300000000000001
# starting with threshold:  0.84
# finished with threshold:  0.84
# starting with threshold:  0.85
# finished with threshold:  0.85
# starting with threshold:  0.86
# finished with threshold:  0.86
# starting with threshold:  0.87
# finished with threshold:  0.87
# starting with threshold:  0.88
# finished with threshold:  0.88
# starting with threshold:  0.89
# finished with threshold:  0.89
# starting with threshold:  0.9
# finished with threshold:  0.9
# starting with threshold:  0.91
# finished with threshold:  0.91
# starting with threshold:  0.92
# finished with threshold:  0.92
# starting with threshold:  0.93
# finished with threshold:  0.93
# starting with threshold:  0.9400000000000001
# finished with threshold:  0.9400000000000001
# starting with threshold:  0.9500000000000001
# finished with threshold:  0.9500000000000001
# starting with threshold:  0.96
# finished with threshold:  0.96
# starting with threshold:  0.97
# finished with threshold:  0.97
# starting with threshold:  0.98
# finished with threshold:  0.98
# starting with threshold:  0.99
# finished with threshold:  0.99
# starting with threshold:  1.0
# finished with threshold:  1.0
# starting with threshold:  1.01
# finished with threshold:  1.01
# starting with threshold:  1.02
# finished with threshold:  1.02
# starting with threshold:  1.03
# finished with threshold:  1.03
# starting with threshold:  1.04
# finished with threshold:  1.04
# starting with threshold:  1.05
# finished with threshold:  1.05
# starting with threshold:  1.06
# finished with threshold:  1.06
# starting with threshold:  1.07
# finished with threshold:  1.07
# starting with threshold:  1.08
# finished with threshold:  1.08
# starting with threshold:  1.09
# finished with threshold:  1.09
# starting with threshold:  1.1
# finished with threshold:  1.1
# starting with threshold:  1.11
# finished with threshold:  1.11
# starting with threshold:  1.12
# finished with threshold:  1.12
# starting with threshold:  1.1300000000000001
# finished with threshold:  1.1300000000000001
# starting with threshold:  1.1400000000000001
# finished with threshold:  1.1400000000000001
# starting with threshold:  1.1500000000000001
# finished with threshold:  1.1500000000000001
# starting with threshold:  1.16
# finished with threshold:  1.16
# starting with threshold:  1.17
# finished with threshold:  1.17
# starting with threshold:  1.18
# finished with threshold:  1.18
# starting with threshold:  1.19
# finished with threshold:  1.19
# starting with threshold:  1.2
# finished with threshold:  1.2
# starting with threshold:  1.21
# finished with threshold:  1.21
# starting with threshold:  1.22
# finished with threshold:  1.22
# starting with threshold:  1.23
# finished with threshold:  1.23
# starting with threshold:  1.24
# finished with threshold:  1.24
# starting with threshold:  1.25
# finished with threshold:  1.25
# starting with threshold:  1.26
# finished with threshold:  1.26
# starting with threshold:  1.27
# finished with threshold:  1.27
# starting with threshold:  1.28
# finished with threshold:  1.28
# starting with threshold:  1.29
# finished with threshold:  1.29
# starting with threshold:  1.3
# finished with threshold:  1.3
# starting with threshold:  1.31
# finished with threshold:  1.31
# starting with threshold:  1.32
# finished with threshold:  1.32
# starting with threshold:  1.33
# finished with threshold:  1.33
# starting with threshold:  1.34
# finished with threshold:  1.34
# starting with threshold:  1.35
# finished with threshold:  1.35
# starting with threshold:  1.36
# finished with threshold:  1.36
# starting with threshold:  1.37
# finished with threshold:  1.37
# starting with threshold:  1.3800000000000001
# finished with threshold:  1.3800000000000001
# starting with threshold:  1.3900000000000001
# finished with threshold:  1.3900000000000001
# starting with threshold:  1.4000000000000001
# finished with threshold:  1.4000000000000001
# starting with threshold:  1.41
# finished with threshold:  1.41
# starting with threshold:  1.42
# finished with threshold:  1.42
# starting with threshold:  1.43
# finished with threshold:  1.43
# starting with threshold:  1.44
# finished with threshold:  1.44
# starting with threshold:  1.45
# finished with threshold:  1.45
# starting with threshold:  1.46
# finished with threshold:  1.46
# starting with threshold:  1.47
# finished with threshold:  1.47
# starting with threshold:  1.48
# finished with threshold:  1.48
# starting with threshold:  1.49
# finished with threshold:  1.49
# starting with threshold:  1.5
# finished with threshold:  1.5
# starting with threshold:  1.51
# finished with threshold:  1.51
# starting with threshold:  1.52
# finished with threshold:  1.52
# starting with threshold:  1.53
# finished with threshold:  1.53
# starting with threshold:  1.54
# finished with threshold:  1.54
# starting with threshold:  1.55
# finished with threshold:  1.55
# starting with threshold:  1.56
# finished with threshold:  1.56
# starting with threshold:  1.57
# finished with threshold:  1.57
# starting with threshold:  1.58
# finished with threshold:  1.58
# starting with threshold:  1.59
# finished with threshold:  1.59
# starting with threshold:  1.6
# finished with threshold:  1.6
# starting with threshold:  1.61
# finished with threshold:  1.61
# starting with threshold:  1.62
# finished with threshold:  1.62
# starting with threshold:  1.6300000000000001
# finished with threshold:  1.6300000000000001
# starting with threshold:  1.6400000000000001
# finished with threshold:  1.6400000000000001
# starting with threshold:  1.6500000000000001
# finished with threshold:  1.6500000000000001
# starting with threshold:  1.6600000000000001
# finished with threshold:  1.6600000000000001
# starting with threshold:  1.67
# finished with threshold:  1.67
# starting with threshold:  1.68
# finished with threshold:  1.68
# starting with threshold:  1.69
# finished with threshold:  1.69
# starting with threshold:  1.7
# finished with threshold:  1.7
# starting with threshold:  1.71
# finished with threshold:  1.71
# starting with threshold:  1.72
# finished with threshold:  1.72
# starting with threshold:  1.73
# finished with threshold:  1.73
# starting with threshold:  1.74
# finished with threshold:  1.74
# starting with threshold:  1.75
# finished with threshold:  1.75
# starting with threshold:  1.76
# finished with threshold:  1.76
# starting with threshold:  1.77
# finished with threshold:  1.77
# starting with threshold:  1.78
# finished with threshold:  1.78
# starting with threshold:  1.79
# finished with threshold:  1.79
# starting with threshold:  1.8
# finished with threshold:  1.8
# starting with threshold:  1.81
# finished with threshold:  1.81
# starting with threshold:  1.82
# finished with threshold:  1.82
# starting with threshold:  1.83
# finished with threshold:  1.83
# starting with threshold:  1.84
# finished with threshold:  1.84
# starting with threshold:  1.85
# finished with threshold:  1.85
# starting with threshold:  1.86
# finished with threshold:  1.86
# starting with threshold:  1.87
# finished with threshold:  1.87
# starting with threshold:  1.8800000000000001
# finished with threshold:  1.8800000000000001
# starting with threshold:  1.8900000000000001
# finished with threshold:  1.8900000000000001
# starting with threshold:  1.9000000000000001
# finished with threshold:  1.9000000000000001
# starting with threshold:  1.9100000000000001
# finished with threshold:  1.9100000000000001
# starting with threshold:  1.92
# finished with threshold:  1.92
# starting with threshold:  1.93
# finished with threshold:  1.93
# starting with threshold:  1.94
# finished with threshold:  1.94
# starting with threshold:  1.95
# finished with threshold:  1.95
# starting with threshold:  1.96
# finished with threshold:  1.96
# starting with threshold:  1.97
# finished with threshold:  1.97
# starting with threshold:  1.98
# finished with threshold:  1.98
# starting with threshold:  1.99
# finished with threshold:  1.99

# %%
mx_train_acc, train_threshold = find_max_accuracies(thresholds, train_accuracies, 'train' )
mx_test_acc, test_threshold = find_max_accuracies(thresholds, test_accuracies, 'test' )

plot_x_y('Accuracy',thresholds,train_accuracies,'Train accuracy')
plot_x_y('Accuracy',thresholds,test_accuracies,'Test accuracy')
# Out:
# Max  train  acc:  0.7255681818181818            Threshold:  0.92
# Max  test  acc:  0.58            Threshold:  0.91
