# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Import all the necessary Library 
import torchvision
import torch.utils.data as utils
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset, random_split
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import time
import copy
from torch.optim import lr_scheduler
import os
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
path_cropped_lfw_folder='./gdrive/MyDrive/Datasets/Cropped_lfw_correct'
path_lfw_folder='./gdrive/MyDrive/Datasets'

# %%
def count_parameters(model):
    temp = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f'The model architecture:\n\n', model)
    print(f'\nThe model has {temp:,} trainable parameters')

def save_checkpoint(save_path, model, optimizer, val_acc):
    if save_path==None:      
        return
    save_path = save_path 
    state_dict = {'model_state_dict': model.state_dict(),                    
                  'optimizer_state_dict': optimizer.state_dict(),
                  'val_accuracy': val_acc}

    torch.save(state_dict, save_path)

    print(f'Model saved to ==> {save_path}')

def load_checkpoint(model, optimizer,save_path):
    state_dict = torch.load(save_path)
    model.load_state_dict(state_dict['model_state_dict'])
    optimizer.load_state_dict(state_dict['optimizer_state_dict'])
    val_acc = state_dict['val_accuracy']
    print(f'Model loaded from <== {save_path}')
    
    return val_acc

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
class Config():
    training_dir = "./gdrive/MyDrive/Datasets/Cropped_lfw_correct"
    testing_dir = "./gdrive/MyDrive/Datasets/Cropped_lfw_correct"
    validation_dir="./gdrive/MyDrive/Datasets/Cropped_lfw_correct"
    train_batch_size = 32
    train_number_epochs = 100
    training_txt="./gdrive/MyDrive/Datasets/LWF_DATASET/pairsDevTrainMod.txt"
    testing_txt="./gdrive/MyDrive/Datasets/LWF_DATASET/pairsDevValidMod.txt"

# %%
class SiameseNetworkDataset():
    
    def __init__(self,training_txt=None,training_dir=None,transform=None):
        self.training_dir = training_dir    
        self.transform = transform
        
        with open(training_txt) as f:
          lines=f.readlines()
          self.training_pairs=[  line.split()       for line in lines  ] 
          for i in range(len(self.training_pairs)):
            self.training_pairs[i][2]=int(self.training_pairs[i][2])
            if self.training_pairs[i][2]==1:                                     # 0 for similar pairs and 1 for dissimilar pairs
              self.training_pairs[i][2]=0
            else:
              self.training_pairs[i][2]=1   

    def __getitem__(self,index):
        
        # getting the image path
        image_pair= self.training_pairs[index]
        image1_path=os.path.join(self.training_dir,image_pair[0])
        image2_path=os.path.join(self.training_dir,image_pair[1])
        
        # Loading the image
        img0 = Image.open(image1_path)
        img1 = Image.open(image2_path)
        
        # Apply image transformations
        if self.transform :
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int( image_pair[2] )],dtype=np.float32))
    
    def __len__(self):
        return len(self.training_pairs)

# %%
class Identity(nn.Module):
  def __init__(self):
    super(Identity,self).__init__()
  
  def forward(self,x):
    return x

# %%
class SiameseNetwork(nn.Module):           # ip=(128,128,3)
  def __init__(self):
    super(SiameseNetwork,self).__init__()

    self.model_vgg16=torchvision.models.vgg16(pretrained=True)                            #### try with vgg paper + other paper
    
    # make the grads off for earlier layers(0 to 23 layers)
    frozen_layers=nn.Sequential(   *(list(self.model_vgg16.children())[0][0:24] )   ) 
    
    for param in frozen_layers.parameters(): 
      param.requires_grad = False

    # self.num_ftrs=self.model_vgg16.features.out_features
  
    self.model_vgg16.avgpool= Identity()

    self.model_vgg16.classifier= nn.Sequential(
        nn.Linear(512*4*4,512),   ### for 128,128,3  ip size
        nn.ReLU(inplace=True),
        nn.Linear(512,512),
        nn.ReLU(inplace=True),
        nn.Linear(512,512),
        nn.ReLU(inplace=True)
    )


  def forward(self,x1,x2):
    x1= self.model_vgg16(x1)            # do we need to flatten ?????? ##################################################################################
    x2= self.model_vgg16(x2)        
    
    return x1,x2

    # pdist = nn.PairwiseDistance(p=2)    ######################################################################## pasot lage ne yeet dile u hbo?
    # output=pdist(x1,x2)                 # x1 and x2 should be like [batch size, 512]

    #                                     # x1=x1.view(-1,self.num_ftrs)
    #                                     # x2=x2.view(-1,self.num_ftrs)

    # return output                        # return the euclidian distance between x1 and x2

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=1.0):
      super(ContrastiveLoss, self).__init__()
      self.margin = margin

    def forward(self, output1,output2, label):                                                
      dist = F.pairwise_distance(output1, output2)
      # loss = torch.mean( 1/2*(label) * torch.pow(dist, 2) + 1/2*(1-label) * torch.pow(torch.clamp(   self.margin - dist ,  min=0.0  ), 2))
      loss= torch.mean(  (1- label) * torch.pow(dist, 2) + (label) * torch.pow( torch.clamp(   self.margin - dist ,  min=0.0  ) , 2)   )
      return loss

# %%
if torch.cuda.is_available():
  device='cuda:0'
  print('Running on gpu')
else:
  device='cpu'
  print('Running on cpu')
# Out:
# Running on gpu

# %%
def calculate_accuracy(labels,preds):
  # preds is a 1 d tensor
  # labels is a (n,1) 2d array

  correct, total=0,0

  for i in range(len(labels)):
    total+=1
    if preds[i]<0.5:  
      # similar predicted
      if labels[i][0]==0.0:
        correct+=1
    else:
      # different predicted
      if labels[i][0]==1.0:
        correct+=1
  return total,correct

# %%
def train(model,train_loader,val_loader,num_epochs,criterion,save_name,optimizer):
  train_losses=[]
  val_losses=[]
  valid_accuracy=[]
  mx_val_accuracy=-1
  counting_batches=0

  for epoch in range(num_epochs):

    running_loss, total_no_imgs = 0.0 , 0
    print("Starting epoch " + str(epoch+1))
    model.train()

    counting_batches=0
    print("Starting training... ")
    for imgs1,imgs2,labels in train_loader:
      counting_batches+=1

      # print("Processing train batch no :",counting_batches)

      imgs1=imgs1.to(device=device, dtype=torch.float)
      imgs2=imgs2.to(device=device, dtype=torch.float)
      labels=labels.to(device=device, dtype=torch.float)

      optimizer.zero_grad()
      
      output1,output2=model(imgs1,imgs2)
      
      # print(output1.size())
      # print(output2.size())

      loss=criterion(output1,output2,labels)                                     ############### dimension problems may arise--- nahile :)
      
      # print(loss)
      # print(loss.item())
      
      loss.backward()
      optimizer.step()

      total_no_imgs+= imgs1.size(0)
      running_loss+=loss.item()* imgs1.size(0)

    avg_train_loss = float(running_loss) /total_no_imgs  
    train_losses.append(avg_train_loss)               

    val_running_loss, correct, total_no_imgs=0.0, 0, 0                                                            
    print("Starting validation... ")
    counting_batches=0
    with torch.no_grad():
      model.eval()
      for i,data in enumerate(val_loader,0):
        counting_batches+=1
        # print("Processing val batch no :",counting_batches)

        imgsV1,imgsV2,labelsV= data
        
        imgsV1=imgsV1.to(device=device, dtype=torch.float)
        imgsV2=imgsV2.to(device=device, dtype=torch.float)
        labelsV=labelsV.to(device=device, dtype=torch.float)

        outputV1, outputV2 = model(imgsV1,imgsV2)
        
        lossV= criterion(outputV1, outputV2,labelsV)
        
        val_running_loss+=lossV.item()*imgsV1.size(0)

        # val accuracy calc  ##################################################################################
        outputV1=outputV1.to(device=device, dtype=torch.float)
        outputV2=outputV2.to(device=device, dtype=torch.float)

        dist = F.pairwise_distance(outputV1, outputV2)     # dist will be a 1d array with each element representing dist for each pair  

        noImg,noCrt= calculate_accuracy(labelsV,dist)
        total_no_imgs+=noImg
        correct+=noCrt
        # print(dist)
        # break#################################################################################################################3
        # for j,op in enumerate(outputs,0):
        #   total_no_imgs+=1
        #   if(op[0]<0.5):
        #     #0 predicted
        #     if labelsV[j]==0:           ###########
        #       correct+=1
        #   else:
        #     # 1 predicted
        #     if labelsV[j]==1:
        #       correct+=1
    # break#################################################################################################################3
    val_accuracy= float(correct)/total_no_imgs
    valid_accuracy.append(val_accuracy)
    
    avg_val_loss= float(val_running_loss)/total_no_imgs
    val_losses.append(avg_val_loss)
    
    ## val acc
    if mx_val_accuracy<val_accuracy:
      mx_val_accuracy=val_accuracy
      save_checkpoint(save_name, model, optimizer, mx_val_accuracy)

    print('Epoch [{}/{}],Train Loss: {:.4f}, Valid Loss: {:.8f}'.format(epoch+1, num_epochs, avg_train_loss, avg_val_loss))
  
  print("Training completed.")
  
  fig = plt.figure()
  ax = plt.subplot(111)
  ax.plot(train_losses)
  ax.plot(val_losses)     ###############3
  plt.xlabel('Steps')  
  plt.ylabel('Loss')  
  fig.savefig(os.path.join(path_lfw_folder,'Loss_Steps.png')) 

  return train_losses,val_losses,mx_val_accuracy,valid_accuracy

# %%
train_dataSize = 2200                                                               
TRAIN_PCT = 0.8 
train_size = int(train_dataSize * TRAIN_PCT)
val_size = train_dataSize - train_size   

siamese_dataset = SiameseNetworkDataset(Config().training_txt,Config().training_dir,
                                        transform=transforms.Compose([transforms.Resize(( 128,128 )),
                                                                      transforms.ToTensor()
                                                                      ])
                                       )

train_set, val_set = random_split(siamese_dataset, [train_size, val_size])


train_loader = DataLoader(train_set, shuffle=True,batch_size=Config().train_batch_size , num_workers=2)    
val_loader   = DataLoader(val_set, shuffle=True, batch_size=1,  num_workers=2)

# %%
# Viewing the sample of images and to check whether its loading properly
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
print(example_batch[2])
# Out:
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [1.]]
# tensor([[1.],
#         [1.],
#         [1.],
#         [1.],
#         [1.],
#         [0.],
#         [1.],
#         [1.]])

# %%
net = SiameseNetwork().cuda()

criterion = ContrastiveLoss()

optimizer = optim.Adam([
                {'params': net.model_vgg16.features[24:31].parameters()},                       ############################################ doubt ase
                {'params': net.model_vgg16.classifier.parameters()}
            ], lr=0.0005)

count_parameters(net)
# Out:
# The model architecture:
#
#  SiameseNetwork(
#   (model_vgg16): VGG(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace=True)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU(inplace=True)
#       (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU(inplace=True)
#       (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (20): ReLU(inplace=True)
#       (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU(inplace=True)
#       (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (25): ReLU(inplace=True)
#       (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (27): ReLU(inplace=True)
#       (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (29): ReLU(inplace=True)
#       (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (avgpool): Identity()
#     (classifier): Sequential(
#       (0): Linear(in_features=8192, out_features=512, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): ReLU(inplace=True)
#       (4): Linear(in_features=512, out_features=512, bias=True)
#       (5): ReLU(inplace=True)
#     )
#   )
# )
#
# The model has 11,799,552 trainable parameters

# %%
save_path=os.path.join(path_lfw_folder,'siameseWithVGG16.pt')

# %%
train_loss_his,val_loss_his,mx_val_accuracy_train,validation_accu=train(net,train_loader,val_loader,Config().train_number_epochs,criterion,save_path,optimizer)
# Out:
# Starting epoch 1
# Starting training...
# Starting validation...
# Model saved to ==> ./gdrive/MyDrive/Datasets/siameseWithVGG16.pt
# Epoch [1/100],Train Loss: 0.2803, Valid Loss: 0.23993872
# Starting epoch 2
# Starting training...
# Starting validation...
# Model saved to ==> ./gdrive/MyDrive/Datasets/siameseWithVGG16.pt
# Epoch [2/100],Train Loss: 0.2692, Valid Loss: 0.24310535
# Starting epoch 3
# Starting training...
# Starting validation...
# Epoch [3/100],Train Loss: 0.2702, Valid Loss: 0.24227970
# Starting epoch 4
# Starting training...
# Starting validation...
# Epoch [4/100],Train Loss: 0.2656, Valid Loss: 0.24263299
# Starting epoch 5
# Starting training...
# Starting validation...
# Epoch [5/100],Train Loss: 0.2642, Valid Loss: 0.24903208
# Starting epoch 6
# Starting training...
# Starting validation...
# Epoch [6/100],Train Loss: 0.2695, Valid Loss: 0.24531493
# Starting epoch 7
# Starting training...
# Starting validation...
# Epoch [7/100],Train Loss: 0.2652, Valid Loss: 0.24551650
# Starting epoch 8
# Starting training...
# Starting validation...
# Epoch [8/100],Train Loss: 0.2593, Valid Loss: 0.25646336
# Starting epoch 9
# Starting training...
# Starting validation...
# Epoch [9/100],Train Loss: 0.2606, Valid Loss: 0.26051200
# Starting epoch 10
# Starting training...
# Starting validation...
# Epoch [10/100],Train Loss: 0.2622, Valid Loss: 0.24435680
# Starting epoch 11
# Starting training...
# Starting validation...
# Epoch [11/100],Train Loss: 0.2583, Valid Loss: 0.24419888
# Starting epoch 12
# Starting training...
# Starting validation...
# Epoch [12/100],Train Loss: 0.2571, Valid Loss: 0.24694261
# Starting epoch 13
# Starting training...
# Starting validation...
# Epoch [13/100],Train Loss: 0.2591, Valid Loss: 0.24319947
# Starting epoch 14
# Starting training...
# Starting validation...
# Epoch [14/100],Train Loss: 0.2571, Valid Loss: 0.24638236
# Starting epoch 15
# Starting training...
# Starting validation...
# Epoch [15/100],Train Loss: 0.2538, Valid Loss: 0.24963802
# Starting epoch 16
# Starting training...
# Starting validation...
# Epoch [16/100],Train Loss: 0.2561, Valid Loss: 0.24877250
# Starting epoch 17
# Starting training...
# Starting validation...
# Epoch [17/100],Train Loss: 0.2555, Valid Loss: 0.24256724
# Starting epoch 18
# Starting training...
# Starting validation...
# Epoch [18/100],Train Loss: 0.2541, Valid Loss: 0.24157123
# Starting epoch 19
# Starting training...
# Starting validation...
# Epoch [19/100],Train Loss: 0.2533, Valid Loss: 0.24922803
# Starting epoch 20
# Starting training...
# Starting validation...
# Model saved to ==> ./gdrive/MyDrive/Datasets/siameseWithVGG16.pt
# Epoch [20/100],Train Loss: 0.2547, Valid Loss: 0.23871660
# Starting epoch 21
# Starting training...
# Starting validation...
# Epoch [21/100],Train Loss: 0.2543, Valid Loss: 0.24388318
# Starting epoch 22
# Starting training...
# Starting validation...
# Epoch [22/100],Train Loss: 0.2533, Valid Loss: 0.24261127
# Starting epoch 23
# Starting training...
# Starting validation...
# Epoch [23/100],Train Loss: 0.2544, Valid Loss: 0.23942555
# Starting epoch 24
# Starting training...
# Starting validation...
# Epoch [24/100],Train Loss: 0.2550, Valid Loss: 0.24869525
# Starting epoch 25
# Starting training...
# Starting validation...
# Epoch [25/100],Train Loss: 0.2543, Valid Loss: 0.24616986
# Starting epoch 26
# Starting training...
# Starting validation...
# Epoch [26/100],Train Loss: 0.2534, Valid Loss: 0.24495994
# Starting epoch 27
# Starting training...
# Starting validation...
# Epoch [27/100],Train Loss: 0.2549, Valid Loss: 0.24555452
# Starting epoch 28
# Starting training...
# Starting validation...
# Epoch [28/100],Train Loss: 0.2537, Valid Loss: 0.24303514
# Starting epoch 29
# Starting training...
# Starting validation...
# Epoch [29/100],Train Loss: 0.2530, Valid Loss: 0.24075693
# Starting epoch 30
# Starting training...
# Starting validation...
# Epoch [30/100],Train Loss: 0.2526, Valid Loss: 0.24459839
# Starting epoch 31
# Starting training...
# Starting validation...
# Epoch [31/100],Train Loss: 0.2543, Valid Loss: 0.24762594
# Starting epoch 32
# Starting training...
# Starting validation...
# Epoch [32/100],Train Loss: 0.2530, Valid Loss: 0.24949608
# Starting epoch 33
# Starting training...
# Starting validation...
# Epoch [33/100],Train Loss: 0.2541, Valid Loss: 0.24971100
# Starting epoch 34
# Starting training...
# Starting validation...
# Epoch [34/100],Train Loss: 0.2535, Valid Loss: 0.24644735
# Starting epoch 35
# Starting training...
# Starting validation...
# Epoch [35/100],Train Loss: 0.2532, Valid Loss: 0.24921921
# Starting epoch 36
# Starting training...
# Starting validation...
# Epoch [36/100],Train Loss: 0.2538, Valid Loss: 0.24628255
# Starting epoch 37
# Starting training...
# Starting validation...
# Epoch [37/100],Train Loss: 0.2534, Valid Loss: 0.24938624
# Starting epoch 38
# Starting training...
# Starting validation...
# Epoch [38/100],Train Loss: 0.2537, Valid Loss: 0.24757582
# Starting epoch 39
# Starting training...
# Starting validation...
# Epoch [39/100],Train Loss: 0.2532, Valid Loss: 0.24438498
# Starting epoch 40
# Starting training...
# Starting validation...
# Epoch [40/100],Train Loss: 0.2534, Valid Loss: 0.24219959
# Starting epoch 41
# Starting training...
# Starting validation...
# Epoch [41/100],Train Loss: 0.2525, Valid Loss: 0.24425354
# Starting epoch 42
# Starting training...
# Starting validation...
# Epoch [42/100],Train Loss: 0.2536, Valid Loss: 0.24518889
# Starting epoch 43
# Starting training...
# Starting validation...
# Epoch [43/100],Train Loss: 0.2535, Valid Loss: 0.24927956
# Starting epoch 44
# Starting training...
# Starting validation...
# Epoch [44/100],Train Loss: 0.2520, Valid Loss: 0.24377882
# Starting epoch 45
# Starting training...
# Starting validation...
# Epoch [45/100],Train Loss: 0.2529, Valid Loss: 0.24664694
# Starting epoch 46
# Starting training...
# Starting validation...
# Epoch [46/100],Train Loss: 0.2527, Valid Loss: 0.24382238
# Starting epoch 47
# Starting training...
# Starting validation...
# Epoch [47/100],Train Loss: 0.2523, Valid Loss: 0.25061581
# Starting epoch 48
# Starting training...
# Starting validation...
# Epoch [48/100],Train Loss: 0.2529, Valid Loss: 0.24610468
# Starting epoch 49
# Starting training...
# Starting validation...
# Epoch [49/100],Train Loss: 0.2531, Valid Loss: 0.24317026
# Starting epoch 50
# Starting training...
# Starting validation...
# Epoch [50/100],Train Loss: 0.2527, Valid Loss: 0.24650430
# Starting epoch 51
# Starting training...
# Starting validation...
# Epoch [51/100],Train Loss: 0.2527, Valid Loss: 0.24758876
# Starting epoch 52
# Starting training...
# Starting validation...
# Epoch [52/100],Train Loss: 0.2527, Valid Loss: 0.24854423
# Starting epoch 53
# Starting training...
# Starting validation...
# Epoch [53/100],Train Loss: 0.2528, Valid Loss: 0.24475899
# Starting epoch 54
# Starting training...
# Starting validation...
# Epoch [54/100],Train Loss: 0.2549, Valid Loss: 0.24343143
# Starting epoch 55
# Starting training...
# Starting validation...
# Epoch [55/100],Train Loss: 0.2541, Valid Loss: 0.24445328
# Starting epoch 56
# Starting training...
# Starting validation...
# Epoch [56/100],Train Loss: 0.2521, Valid Loss: 0.24896007
# Starting epoch 57
# Starting training...
# Starting validation...
# Epoch [57/100],Train Loss: 0.2529, Valid Loss: 0.24184086
# Starting epoch 58
# Starting training...
# Epoch [58/100],Train Loss: 0.2523, Valid Loss: 0.24876337
# Starting epoch 59
# Starting training...
# Starting validation...
# Epoch [59/100],Train Loss: 0.2527, Valid Loss: 0.24693172
# Starting epoch 60
# Starting training...
# Starting validation...
# Epoch [60/100],Train Loss: 0.2525, Valid Loss: 0.24604921
# Starting epoch 61
# Starting training...
# Starting validation...
# Epoch [61/100],Train Loss: 0.2541, Valid Loss: 0.24591811
# Starting epoch 62
# Starting training...
# Starting validation...
# Epoch [62/100],Train Loss: 0.2524, Valid Loss: 0.24511799
# Starting epoch 63
# Starting training...
# Starting validation...
# Epoch [63/100],Train Loss: 0.2529, Valid Loss: 0.24568418
# Starting epoch 64
# Starting training...
# Starting validation...
# Epoch [64/100],Train Loss: 0.2543, Valid Loss: 0.24176410
# Starting epoch 65
# Starting training...
# Starting validation...
# Epoch [65/100],Train Loss: 0.2534, Valid Loss: 0.24366380
# Starting epoch 66
# Starting training...
# Starting validation...
# Epoch [66/100],Train Loss: 0.2526, Valid Loss: 0.24138867
# Starting epoch 67
# Starting training...
# Starting validation...
# Epoch [67/100],Train Loss: 0.2536, Valid Loss: 0.24619985
# Starting epoch 68
# Starting training...
# Starting validation...
# Epoch [68/100],Train Loss: 0.2531, Valid Loss: 0.24510516
# Starting epoch 69
# Starting training...
# Starting validation...
# Epoch [69/100],Train Loss: 0.2525, Valid Loss: 0.24850452
# Starting epoch 70
# Starting training...
# Starting validation...
# Epoch [70/100],Train Loss: 0.2545, Valid Loss: 0.24489715
# Starting epoch 71
# Starting training...
# Starting validation...
# Epoch [71/100],Train Loss: 0.2529, Valid Loss: 0.24649564
# Starting epoch 72
# Starting training...
# Starting validation...
# Epoch [72/100],Train Loss: 0.2530, Valid Loss: 0.25008487
# Starting epoch 73
# Starting training...
# Starting validation...
# Epoch [73/100],Train Loss: 0.2550, Valid Loss: 0.24245786
# Starting epoch 74
# Starting training...
# Starting validation...
# Epoch [74/100],Train Loss: 0.2530, Valid Loss: 0.24500384
# Starting epoch 75
# Starting training...
# Starting validation...
# Epoch [75/100],Train Loss: 0.2535, Valid Loss: 0.24527228
# Starting epoch 76
# Starting training...
# Starting validation...
# Epoch [76/100],Train Loss: 0.2534, Valid Loss: 0.24684040
# Starting epoch 77
# Starting training...
# Starting validation...
# Epoch [77/100],Train Loss: 0.2526, Valid Loss: 0.24531572
# Starting epoch 78
# Starting training...
# Starting validation...
# Epoch [78/100],Train Loss: 0.2531, Valid Loss: 0.24741280
# Starting epoch 79
# Starting training...
# Starting validation...
# Epoch [79/100],Train Loss: 0.2528, Valid Loss: 0.24356347
# Starting epoch 80
# Starting training...
# Starting validation...
# Epoch [80/100],Train Loss: 0.2522, Valid Loss: 0.24138279
# Starting epoch 81
# Starting training...
# Starting validation...
# Epoch [81/100],Train Loss: 0.2523, Valid Loss: 0.24584944
# Starting epoch 82
# Starting training...
# Starting validation...
# Epoch [82/100],Train Loss: 0.2526, Valid Loss: 0.24511044
# Starting epoch 83
# Starting training...
# Starting validation...
# Epoch [83/100],Train Loss: 0.2526, Valid Loss: 0.24403916
# Starting epoch 84
# Starting training...
# Starting validation...
# Epoch [84/100],Train Loss: 0.2523, Valid Loss: 0.24566828
# Starting epoch 85
# Starting training...
# Starting validation...
# Epoch [85/100],Train Loss: 0.2521, Valid Loss: 0.24693619
# Starting epoch 86
# Starting training...
# Starting validation...
# Epoch [86/100],Train Loss: 0.2524, Valid Loss: 0.24926341
# Starting epoch 87
# Starting training...
# Starting validation...
# Epoch [87/100],Train Loss: 0.2535, Valid Loss: 0.24706568
# Starting epoch 88
# Starting training...
# Starting validation...
# Epoch [88/100],Train Loss: 0.2532, Valid Loss: 0.24519091
# Starting epoch 89
# Starting training...
# Starting validation...
# Epoch [89/100],Train Loss: 0.2533, Valid Loss: 0.25007171
# Starting epoch 90
# Starting training...
# Starting validation...
# Epoch [90/100],Train Loss: 0.2531, Valid Loss: 0.24317043
# Starting epoch 91
# Starting training...
# Starting validation...
# Epoch [91/100],Train Loss: 0.2527, Valid Loss: 0.24456703
# Starting epoch 92
# Starting training...
# Starting validation...
# Epoch [92/100],Train Loss: 0.2530, Valid Loss: 0.24464317
# Starting epoch 93
# Starting training...
# Starting validation...
# Epoch [93/100],Train Loss: 0.2532, Valid Loss: 0.24469740
# Starting epoch 94
# Starting training...
# Starting validation...
# Epoch [94/100],Train Loss: 0.2541, Valid Loss: 0.24512284
# Starting epoch 95
# Starting training...
# Starting validation...
# Epoch [95/100],Train Loss: 0.2520, Valid Loss: 0.25193461
# Starting epoch 96
# Starting training...
# Starting validation...
# Epoch [96/100],Train Loss: 0.2544, Valid Loss: 0.24697044
# Starting epoch 97
# Starting training...
# Starting validation...
# Epoch [97/100],Train Loss: 0.2529, Valid Loss: 0.24414939
# Starting epoch 98
# Starting training...
# Starting validation...
# Epoch [98/100],Train Loss: 0.2527, Valid Loss: 0.24730524
# Starting epoch 99
# Starting training...
# Starting validation...
# Epoch [99/100],Train Loss: 0.2520, Valid Loss: 0.24628862
# Starting epoch 100
# Starting training...
# Starting validation...
# Epoch [100/100],Train Loss: 0.2522, Valid Loss: 0.25048097
# Training completed.

# %%
# lr=    batch=   epoch=
plt.ylabel('loss')
plt.plot(train_loss_his, label='Train Loss')
plt.plot(val_loss_his, label='Validation Loss')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %%
# lr=    batch=   epoch=
plt.ylabel('validation accuracy')
plt.plot(validation_accu, label='Validation accuracy')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %%
print("Maximum validation accuracy: ",mx_val_accuracy_train)
# Out:
# Maximum validation accuracy:  0.5886363636363636

# %%
def test(model,test_loader):
    with torch.no_grad():
      model.eval()
      correct=0
      cnt=0
      bth_no=0
      print("Strating ...")
      for i,data in enumerate(test_loader,0):
        bth_no+=1
        print("Batch no: ",bth_no)
        
        imgs1,imgs2,labels=data
        
        imgs1=imgs1.to(device=device, dtype=torch.float)
        imgs2=imgs2.to(device=device, dtype=torch.float)
        labels=labels.to(device=device, dtype=torch.float)

        output1,output2=model(imgs1,imgs2)

        dist = F.pairwise_distance(output1, output2)     # dist will be a 1d array with each element representing dist for each pair  

        noImg,noCrt= calculate_accuracy(labels,dist)
        cnt+=noImg
        correct+=noCrt

    test_accuracy= correct/cnt
    print("Finished!!!")

    return test_accuracy

# %%
root_path_to_saved_models=path_lfw_folder
path_to_model_from_saved_model_dir='siameseWithVGG16.pt'
path_to_chosen_model= os.path.join(root_path_to_saved_models,path_to_model_from_saved_model_dir)  #################
# print(path_to_chosen_model )

# %%
load_model= SiameseNetwork().cuda()
load_optimizer = optim.Adam([
                {'params': load_model.model_vgg16.features[24:31].parameters()},                       ############################################ doubt ase
                {'params': load_model.model_vgg16.classifier.parameters()}
            ], lr=0.0005)
mx_val_acc=load_checkpoint(load_model,load_optimizer,path_to_chosen_model)

#########################################

siamese_dataset_test = SiameseNetworkDataset(Config().testing_txt,Config().testing_dir,
                                        transform=transforms.Compose([transforms.Resize(( 128,128 )),
                                                                      transforms.ToTensor()
                                                  ])
                                        )
test_loader = DataLoader(siamese_dataset_test , shuffle=True, batch_size=1,  num_workers=2)

train_accuracy= test(load_model,train_loader)
test_accuracy=test(load_model,test_loader)


print("Train accuracy is: ",100*train_accuracy)
print("Test accuracy is: ",100*test_accuracy)
print("Max val accuracy during training: ",100*mx_val_acc)
# Out:
# Model loaded from <== ./gdrive/MyDrive/Datasets/siameseWithVGG16.pt
# Strating ...
# Batch no:  1
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Batch no:  2
# Batch no:  3
# Batch no:  4
# Batch no:  5
# Batch no:  6
# Batch no:  7
# Batch no:  8
# Batch no:  9
# Batch no:  10
# Batch no:  11
# Batch no:  12
# Batch no:  13
# Batch no:  14
# Batch no:  15
# Batch no:  16
# Batch no:  17
# Batch no:  18
# Batch no:  19
# Batch no:  20
# Batch no:  21
# Batch no:  22
# Batch no:  23
# Batch no:  24
# Batch no:  25
# Batch no:  26
# Batch no:  27
# Batch no:  28
# Batch no:  29
# Batch no:  30
# Batch no:  31
# Batch no:  32
# Batch no:  33
# Batch no:  34
# Batch no:  35
# Batch no:  36
# Batch no:  37
# Batch no:  38
# Batch no:  39
# Batch no:  40
# Batch no:  41
# Batch no:  42
# Batch no:  43
# Batch no:  44
# Batch no:  45
# Batch no:  46
# Batch no:  47
# Batch no:  48
# Batch no:  49
# Batch no:  50
# Batch no:  51
# Batch no:  52
# Batch no:  53
# Batch no:  54
# Batch no:  55
# Finished!!!
# Strating ...
# Batch no:  1
# Batch no:  2
# Batch no:  3
# Batch no:  4
# Batch no:  5
# Batch no:  6
# Batch no:  7
# Batch no:  8
# Batch no:  9
# Batch no:  10
# Batch no:  11
# Batch no:  12
# Batch no:  13
# Batch no:  14
# Batch no:  15
# Batch no:  16
# Batch no:  17
# Batch no:  18
# Batch no:  19
# Batch no:  20
# Batch no:  21
# Batch no:  22
# Batch no:  23
# Batch no:  24
# Batch no:  25
# Batch no:  26
# Batch no:  27
# Batch no:  28
# Batch no:  29
# Batch no:  30
# Batch no:  31
# Batch no:  32
# Batch no:  33
# Batch no:  34
# Batch no:  35
# Batch no:  36
# Batch no:  37
# Batch no:  38
# Batch no:  39
# Batch no:  40
# Batch no:  41
# Batch no:  42
# Batch no:  43
# Batch no:  44
# Batch no:  45
# Batch no:  46
# Batch no:  47
# Batch no:  48
# Batch no:  49
# Batch no:  50
# Batch no:  51
# Batch no:  52
# Batch no:  53
# Batch no:  54
# Batch no:  55
# Batch no:  56
# Batch no:  57
# Batch no:  58
# Batch no:  59
# Batch no:  60
# Batch no:  61
# Batch no:  62
# Batch no:  63
# Batch no:  64
# Batch no:  65
# Batch no:  66
# Batch no:  67
# Batch no:  68
# Batch no:  69
# Batch no:  70
# Batch no:  71
# Batch no:  72
# Batch no:  73
# Batch no:  74
# Batch no:  75
# Batch no:  76
# Batch no:  77
# Batch no:  78
# Batch no:  79
# Batch no:  80
# Batch no:  81
# Batch no:  82
# Batch no:  83
# Batch no:  84
# Batch no:  85
# Batch no:  86
# Batch no:  87
# Batch no:  88
# Batch no:  89
# Batch no:  90
# Batch no:  91
# Batch no:  92
# Batch no:  93
# Batch no:  94
# Batch no:  95
# Batch no:  96
# Batch no:  97
# Batch no:  98
# Batch no:  99
# Batch no:  100
# Batch no:  101
# Batch no:  102
# Batch no:  103
# Batch no:  104
# Batch no:  105
# Batch no:  106
# Batch no:  107
# Batch no:  108
# Batch no:  109
# Batch no:  110
# Batch no:  111
# Batch no:  112
# Batch no:  113
# Batch no:  114
# Batch no:  115
# Batch no:  116
# Batch no:  117
# Batch no:  118
# Batch no:  119
# Batch no:  120
# Batch no:  121
# Batch no:  122
# Batch no:  123
# Batch no:  124
# Batch no:  125
# Batch no:  126
# Batch no:  127
# Batch no:  128
# Batch no:  129
# Batch no:  130
# Batch no:  131
# Batch no:  132
# Batch no:  133
# Batch no:  134
# Batch no:  135
# Batch no:  136
# Batch no:  137
# Batch no:  138
# Batch no:  139
# Batch no:  140
# Batch no:  141
# Batch no:  142
# Batch no:  143
# Batch no:  144
# Batch no:  145
# Batch no:  146
# Batch no:  147
# Batch no:  148
# Batch no:  149
# Batch no:  150
# Batch no:  151
# Batch no:  152
# Batch no:  153
# Batch no:  154
# Batch no:  155
# Batch no:  156
# Batch no:  157
# Batch no:  158
# Batch no:  159
# Batch no:  160
# Batch no:  161
# Batch no:  162
# Batch no:  163
# Batch no:  164
# Batch no:  165
# Batch no:  166
# Batch no:  167
# Batch no:  168
# Batch no:  169
# Batch no:  170
# Batch no:  171
# Batch no:  172
# Batch no:  173
# Batch no:  174
# Batch no:  175
# Batch no:  176
# Batch no:  177
# Batch no:  178
# Batch no:  179
# Batch no:  180
# Batch no:  181
# Batch no:  182
# Batch no:  183
# Batch no:  184
# Batch no:  185
# Batch no:  186
# Batch no:  187
# Batch no:  188
# Batch no:  189
# Batch no:  190
# Batch no:  191
# Batch no:  192
# Batch no:  193
# Batch no:  194
# Batch no:  195
# Batch no:  196
# Batch no:  197
# Batch no:  198
# Batch no:  199
# Batch no:  200
# Batch no:  201
# Batch no:  202
# Batch no:  203
# Batch no:  204
# Batch no:  205
# Batch no:  206
# Batch no:  207
# Batch no:  208
# Batch no:  209
# Batch no:  210
# Batch no:  211
# Batch no:  212
# Batch no:  213
# Batch no:  214
# Batch no:  215
# Batch no:  216
# Batch no:  217
# Batch no:  218
# Batch no:  219
# Batch no:  220
# Batch no:  221
# Batch no:  222
# Batch no:  223
# Batch no:  224
# Batch no:  225
# Batch no:  226
# Batch no:  227
# Batch no:  228
# Batch no:  229
# Batch no:  230
# Batch no:  231
# Batch no:  232
# Batch no:  233
# Batch no:  234
# Batch no:  235
# Batch no:  236
# Batch no:  237
# Batch no:  238
# Batch no:  239
# Batch no:  240
# Batch no:  241
# Batch no:  242
# Batch no:  243
# Batch no:  244
# Batch no:  245
# Batch no:  246
# Batch no:  247
# Batch no:  248
# Batch no:  249
# Batch no:  250
# Batch no:  251
# Batch no:  252
# Batch no:  253
# Batch no:  254
# Batch no:  255
# Batch no:  256
# Batch no:  257
# Batch no:  258
# Batch no:  259
# Batch no:  260
# Batch no:  261
# Batch no:  262
# Batch no:  263
# Batch no:  264
# Batch no:  265
# Batch no:  266
# Batch no:  267
# Batch no:  268
# Batch no:  269
# Batch no:  270
# Batch no:  271
# Batch no:  272
# Batch no:  273
# Batch no:  274
# Batch no:  275
# Batch no:  276
# Batch no:  277
# Batch no:  278
# Batch no:  279
# Batch no:  280
# Batch no:  281
# Batch no:  282
# Batch no:  283
# Batch no:  284
# Batch no:  285
# Batch no:  286
# Batch no:  287
# Batch no:  288
# Batch no:  289
# Batch no:  290
# Batch no:  291
# Batch no:  292
# Batch no:  293
# Batch no:  294
# Batch no:  295
# Batch no:  296
# Batch no:  297
# Batch no:  298
# Batch no:  299
# Batch no:  300
# Batch no:  301
# Batch no:  302
# Batch no:  303
# Batch no:  304
# Batch no:  305
# Batch no:  306
# Batch no:  307
# Batch no:  308
# Batch no:  309
# Batch no:  310
# Batch no:  311
# Batch no:  312
# Batch no:  313
# Batch no:  314
# Batch no:  315
# Batch no:  316
# Batch no:  317
# Batch no:  318
# Batch no:  319
# Batch no:  320
# Batch no:  321
# Batch no:  322
# Batch no:  323
# Batch no:  324
# Batch no:  325
# Batch no:  326
# Batch no:  327
# Batch no:  328
# Batch no:  329
# Batch no:  330
# Batch no:  331
# Batch no:  332
# Batch no:  333
# Batch no:  334
# Batch no:  335
# Batch no:  336
# Batch no:  337
# Batch no:  338
# Batch no:  339
# Batch no:  340
# Batch no:  341
# Batch no:  342
# Batch no:  343
# Batch no:  344
# Batch no:  345
# Batch no:  346
# Batch no:  347
# Batch no:  348
# Batch no:  349
# Batch no:  350
# Batch no:  351
# Batch no:  352
# Batch no:  353
# Batch no:  354
# Batch no:  355
# Batch no:  356
# Batch no:  357
# Batch no:  358
# Batch no:  359
# Batch no:  360
# Batch no:  361
# Batch no:  362
# Batch no:  363
# Batch no:  364
# Batch no:  365
# Batch no:  366
# Batch no:  367
# Batch no:  368
# Batch no:  369
# Batch no:  370
# Batch no:  371
# Batch no:  372
# Batch no:  373
# Batch no:  374
# Batch no:  375
# Batch no:  376
# Batch no:  377
# Batch no:  378
# Batch no:  379
# Batch no:  380
# Batch no:  381
# Batch no:  382
# Batch no:  383
# Batch no:  384
# Batch no:  385
# Batch no:  386
# Batch no:  387
# Batch no:  388
# Batch no:  389
# Batch no:  390
# Batch no:  391
# Batch no:  392
# Batch no:  393
# Batch no:  394
# Batch no:  395
# Batch no:  396
# Batch no:  397
# Batch no:  398
# Batch no:  399
# Batch no:  400
# Batch no:  401
# Batch no:  402
# Batch no:  403
# Batch no:  404
# Batch no:  405
# Batch no:  406
# Batch no:  407
# Batch no:  408
# Batch no:  409
# Batch no:  410
# Batch no:  411
# Batch no:  412
# Batch no:  413
# Batch no:  414
# Batch no:  415
# Batch no:  416
# Batch no:  417
# Batch no:  418
# Batch no:  419
# Batch no:  420
# Batch no:  421
# Batch no:  422
# Batch no:  423
# Batch no:  424
# Batch no:  425
# Batch no:  426
# Batch no:  427
# Batch no:  428
# Batch no:  429
# Batch no:  430
# Batch no:  431
# Batch no:  432
# Batch no:  433
# Batch no:  434
# Batch no:  435
# Batch no:  436
# Batch no:  437
# Batch no:  438
# Batch no:  439
# Batch no:  440
# Batch no:  441
# Batch no:  442
# Batch no:  443
# Batch no:  444
# Batch no:  445
# Batch no:  446
# Batch no:  447
# Batch no:  448
# Batch no:  449
# Batch no:  450
# Batch no:  451
# Batch no:  452
# Batch no:  453
# Batch no:  454
# Batch no:  455
# Batch no:  456
# Batch no:  457
# Batch no:  458
# Batch no:  459
# Batch no:  460
# Batch no:  461
# Batch no:  462
# Batch no:  463
# Batch no:  464
# Batch no:  465
# Batch no:  466
# Batch no:  467
# Batch no:  468
# Batch no:  469
# Batch no:  470
# Batch no:  471
# Batch no:  472
# Batch no:  473
# Batch no:  474
# Batch no:  475
# Batch no:  476
# Batch no:  477
# Batch no:  478
# Batch no:  479
# Batch no:  480
# Batch no:  481
# Batch no:  482
# Batch no:  483
# Batch no:  484
# Batch no:  485
# Batch no:  486
# Batch no:  487
# Batch no:  488
# Batch no:  489
# Batch no:  490
# Batch no:  491
# Batch no:  492
# Batch no:  493
# Batch no:  494
# Batch no:  495
# Batch no:  496
# Batch no:  497
# Batch no:  498
# Batch no:  499
# Batch no:  500
# Batch no:  501
# Batch no:  502
# Batch no:  503
# Batch no:  504
# Batch no:  505
# Batch no:  506
# Batch no:  507
# Batch no:  508
# Batch no:  509
# Batch no:  510
# Batch no:  511
# Batch no:  512
# Batch no:  513
# Batch no:  514
# Batch no:  515
# Batch no:  516
# Batch no:  517
# Batch no:  518
# Batch no:  519
# Batch no:  520
# Batch no:  521
# Batch no:  522
# Batch no:  523
# Batch no:  524
# Batch no:  525
# Batch no:  526
# Batch no:  527
# Batch no:  528
# Batch no:  529
# Batch no:  530
# Batch no:  531
# Batch no:  532
# Batch no:  533
# Batch no:  534
# Batch no:  535
# Batch no:  536
# Batch no:  537
# Batch no:  538
# Batch no:  539
# Batch no:  540
# Batch no:  541
# Batch no:  542
# Batch no:  543
# Batch no:  544
# Batch no:  545
# Batch no:  546
# Batch no:  547
# Batch no:  548
# Batch no:  549
# Batch no:  550
# Batch no:  551
# Batch no:  552
# Batch no:  553
# Batch no:  554
# Batch no:  555
# Batch no:  556
# Batch no:  557
# Batch no:  558
# Batch no:  559
# Batch no:  560
# Batch no:  561
# Batch no:  562
# Batch no:  563
# Batch no:  564
# Batch no:  565
# Batch no:  566
# Batch no:  567
# Batch no:  568
# Batch no:  569
# Batch no:  570
# Batch no:  571
# Batch no:  572
# Batch no:  573
# Batch no:  574
# Batch no:  575
# Batch no:  576
# Batch no:  577
# Batch no:  578
# Batch no:  579
# Batch no:  580
# Batch no:  581
# Batch no:  582
# Batch no:  583
# Batch no:  584
# Batch no:  585
# Batch no:  586
# Batch no:  587
# Batch no:  588
# Batch no:  589
# Batch no:  590
# Batch no:  591
# Batch no:  592
# Batch no:  593
# Batch no:  594
# Batch no:  595
# Batch no:  596
# Batch no:  597
# Batch no:  598
# Batch no:  599
# Batch no:  600
# Batch no:  601
# Batch no:  602
# Batch no:  603
# Batch no:  604
# Batch no:  605
# Batch no:  606
# Batch no:  607
# Batch no:  608
# Batch no:  609
# Batch no:  610
# Batch no:  611
# Batch no:  612
# Batch no:  613
# Batch no:  614
# Batch no:  615
# Batch no:  616
# Batch no:  617
# Batch no:  618
# Batch no:  619
# Batch no:  620
# Batch no:  621
# Batch no:  622
# Batch no:  623
# Batch no:  624
# Batch no:  625
# Batch no:  626
# Batch no:  627
# Batch no:  628
# Batch no:  629
# Batch no:  630
# Batch no:  631
# Batch no:  632
# Batch no:  633
# Batch no:  634
# Batch no:  635
# Batch no:  636
# Batch no:  637
# Batch no:  638
# Batch no:  639
# Batch no:  640
# Batch no:  641
# Batch no:  642
# Batch no:  643
# Batch no:  644
# Batch no:  645
# Batch no:  646
# Batch no:  647
# Batch no:  648
# Batch no:  649
# Batch no:  650
# Batch no:  651
# Batch no:  652
# Batch no:  653
# Batch no:  654
# Batch no:  655
# Batch no:  656
# Batch no:  657
# Batch no:  658
# Batch no:  659
# Batch no:  660
# Batch no:  661
# Batch no:  662
# Batch no:  663
# Batch no:  664
# Batch no:  665
# Batch no:  666
# Batch no:  667
# Batch no:  668
# Batch no:  669
# Batch no:  670
# Batch no:  671
# Batch no:  672
# Batch no:  673
# Batch no:  674
# Batch no:  675
# Batch no:  676
# Batch no:  677
# Batch no:  678
# Batch no:  679
# Batch no:  680
# Batch no:  681
# Batch no:  682
# Batch no:  683
# Batch no:  684
# Batch no:  685
# Batch no:  686
# Batch no:  687
# Batch no:  688
# Batch no:  689
# Batch no:  690
# Batch no:  691
# Batch no:  692
# Batch no:  693
# Batch no:  694
# Batch no:  695
# Batch no:  696
# Batch no:  697
# Batch no:  698
# Batch no:  699
# Batch no:  700
# Batch no:  701
# Batch no:  702
# Batch no:  703
# Batch no:  704
# Batch no:  705
# Batch no:  706
# Batch no:  707
# Batch no:  708
# Batch no:  709
# Batch no:  710
# Batch no:  711
# Batch no:  712
# Batch no:  713
# Batch no:  714
# Batch no:  715
# Batch no:  716
# Batch no:  717
# Batch no:  718
# Batch no:  719
# Batch no:  720
# Batch no:  721
# Batch no:  722
# Batch no:  723
# Batch no:  724
# Batch no:  725
# Batch no:  726
# Batch no:  727
# Batch no:  728
# Batch no:  729
# Batch no:  730
# Batch no:  731
# Batch no:  732
# Batch no:  733
# Batch no:  734
# Batch no:  735
# Batch no:  736
# Batch no:  737
# Batch no:  738
# Batch no:  739
# Batch no:  740
# Batch no:  741
# Batch no:  742
# Batch no:  743
# Batch no:  744
# Batch no:  745
# Batch no:  746
# Batch no:  747
# Batch no:  748
# Batch no:  749
# Batch no:  750
# Batch no:  751
# Batch no:  752
# Batch no:  753
# Batch no:  754
# Batch no:  755
# Batch no:  756
# Batch no:  757
# Batch no:  758
# Batch no:  759
# Batch no:  760
# Batch no:  761
# Batch no:  762
# Batch no:  763
# Batch no:  764
# Batch no:  765
# Batch no:  766
# Batch no:  767
# Batch no:  768
# Batch no:  769
# Batch no:  770
# Batch no:  771
# Batch no:  772
# Batch no:  773
# Batch no:  774
# Batch no:  775
# Batch no:  776
# Batch no:  777
# Batch no:  778
# Batch no:  779
# Batch no:  780
# Batch no:  781
# Batch no:  782
# Batch no:  783
# Batch no:  784
# Batch no:  785
# Batch no:  786
# Batch no:  787
# Batch no:  788
# Batch no:  789
# Batch no:  790
# Batch no:  791
# Batch no:  792
# Batch no:  793
# Batch no:  794
# Batch no:  795
# Batch no:  796
# Batch no:  797
# Batch no:  798
# Batch no:  799
# Batch no:  800
# Batch no:  801
# Batch no:  802
# Batch no:  803
# Batch no:  804
# Batch no:  805
# Batch no:  806
# Batch no:  807
# Batch no:  808
# Batch no:  809
# Batch no:  810
# Batch no:  811
# Batch no:  812
# Batch no:  813
# Batch no:  814
# Batch no:  815
# Batch no:  816
# Batch no:  817
# Batch no:  818
# Batch no:  819
# Batch no:  820
# Batch no:  821
# Batch no:  822
# Batch no:  823
# Batch no:  824
# Batch no:  825
# Batch no:  826
# Batch no:  827
# Batch no:  828
# Batch no:  829
# Batch no:  830
# Batch no:  831
# Batch no:  832
# Batch no:  833
# Batch no:  834
# Batch no:  835
# Batch no:  836
# Batch no:  837
# Batch no:  838
# Batch no:  839
# Batch no:  840
# Batch no:  841
# Batch no:  842
# Batch no:  843
# Batch no:  844
# Batch no:  845
# Batch no:  846
# Batch no:  847
# Batch no:  848
# Batch no:  849
# Batch no:  850
# Batch no:  851
# Batch no:  852
# Batch no:  853
# Batch no:  854
# Batch no:  855
# Batch no:  856
# Batch no:  857
# Batch no:  858
# Batch no:  859
# Batch no:  860
# Batch no:  861
# Batch no:  862
# Batch no:  863
# Batch no:  864
# Batch no:  865
# Batch no:  866
# Batch no:  867
# Batch no:  868
# Batch no:  869
# Batch no:  870
# Batch no:  871
# Batch no:  872
# Batch no:  873
# Batch no:  874
# Batch no:  875
# Batch no:  876
# Batch no:  877
# Batch no:  878
# Batch no:  879
# Batch no:  880
# Batch no:  881
# Batch no:  882
# Batch no:  883
# Batch no:  884
# Batch no:  885
# Batch no:  886
# Batch no:  887
# Batch no:  888
# Batch no:  889
# Batch no:  890
# Batch no:  891
# Batch no:  892
# Batch no:  893
# Batch no:  894
# Batch no:  895
# Batch no:  896
# Batch no:  897
# Batch no:  898
# Batch no:  899
# Batch no:  900
# Batch no:  901
# Batch no:  902
# Batch no:  903
# Batch no:  904
# Batch no:  905
# Batch no:  906
# Batch no:  907
# Batch no:  908
# Batch no:  909
# Batch no:  910
# Batch no:  911
# Batch no:  912
# Batch no:  913
# Batch no:  914
# Batch no:  915
# Batch no:  916
# Batch no:  917
# Batch no:  918
# Batch no:  919
# Batch no:  920
# Batch no:  921
# Batch no:  922
# Batch no:  923
# Batch no:  924
# Batch no:  925
# Batch no:  926
# Batch no:  927
# Batch no:  928
# Batch no:  929
# Batch no:  930
# Batch no:  931
# Batch no:  932
# Batch no:  933
# Batch no:  934
# Batch no:  935
# Batch no:  936
# Batch no:  937
# Batch no:  938
# Batch no:  939
# Batch no:  940
# Batch no:  941
# Batch no:  942
# Batch no:  943
# Batch no:  944
# Batch no:  945
# Batch no:  946
# Batch no:  947
# Batch no:  948
# Batch no:  949
# Batch no:  950
# Batch no:  951
# Batch no:  952
# Batch no:  953
# Batch no:  954
# Batch no:  955
# Batch no:  956
# Batch no:  957
# Batch no:  958
# Batch no:  959
# Batch no:  960
# Batch no:  961
# Batch no:  962
# Batch no:  963
# Batch no:  964
# Batch no:  965
# Batch no:  966
# Batch no:  967
# Batch no:  968
# Batch no:  969
# Batch no:  970
# Batch no:  971
# Batch no:  972
# Batch no:  973
# Batch no:  974
# Batch no:  975
# Batch no:  976
# Batch no:  977
# Batch no:  978
# Batch no:  979
# Batch no:  980
# Batch no:  981
# Batch no:  982
# Batch no:  983
# Batch no:  984
# Batch no:  985
# Batch no:  986
# Batch no:  987
# Batch no:  988
# Batch no:  989
# Batch no:  990
# Batch no:  991
# Batch no:  992
# Batch no:  993
# Batch no:  994
# Batch no:  995
# Batch no:  996
# Batch no:  997
# Batch no:  998
# Batch no:  999
# Batch no:  1000
# Finished!!!
# Train accuracy is:  60.39772727272727
# Test accuracy is:  54.7
# Max val accuracy during training:  58.86363636363636

# %%
print("Train accuracy is: ",100*train_accuracy)
print("Test accuracy is: ",100*test_accuracy)
print("Max val accuracy during training: ",100*mx_val_acc)
# Out:
# Train accuracy is:  60.39772727272727
# Test accuracy is:  54.7
# Max val accuracy during training:  58.86363636363636

# %% [markdown]
# # Experiment

# %%
pdist = nn.PairwiseDistance(p=2)

input1 = torch.randn(5, 512)
input2 = torch.randn(5, 512)

c= F.pairwise_distance(input1, input2)
output = pdist(input1, input2)

# print(c.size())

# print(output) # this is the pair wise distance 


for i in output:
  if i>0.5:
    print("correct :",i)
# Out:
# correct : tensor(31.7107)
# correct : tensor(31.1265)
# correct : tensor(32.0591)
# correct : tensor(30.8274)
# correct : tensor(32.9686)
